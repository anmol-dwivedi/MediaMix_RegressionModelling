# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
import sys
import os
import time


from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold
from sklearn.feature_selection import RFECV, RFE

from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet

from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.model_selection import GridSearchCV

from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE

import mlflow
import mlflow.statsmodels
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor


import warnings
warnings.filterwarnings("ignore")
pd.set_option("display.float_format", "{:.4f}".format)

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Data Ingestion

# %%
df = pd.read_csv("Modelling_Data/cameraAcc_final2.csv")
df.head()
# Out:
#    order_week  Month  Year  adStock_Traditional Marketing  \
# 0          27      7  2015                         2.8611
# 1          28      7  2015                         3.3379
# 2          29      7  2015                         3.5764
# 3          30      7  2015                         3.6956
# 4          31      7  2015                         3.7552
#
#    adStock_Digital Marketing  adStock_Partnership Marketing  \
# 0                     3.3318                         2.9856
# 1                     3.8872                         3.4832
# 2                     4.1648                         3.7320
# 3                     4.3036                         3.8564
# 4                     4.3730                         3.9186
#
#    adStock_Other Marketing          gmv  units    sla  \
# 0                   0.0000   15375.0000     25 2.2800
# 1                   0.0000 2019042.0000   2752 7.1563
# 2                   0.0000 2249245.0000   2917 6.4913
# 3                   0.0000 2105858.0000   2888 6.4881
# 4                   0.0000 1426134.0000   1932 6.4707
#
#    product_procurement_sla  product_mrp  selling_price     NPS  discount  \
# 0                   2.9600    1456.8400       615.0000 54.5996    0.5256
# 1                   2.7426    1646.4281       751.2335 54.5996    0.4622
# 2                   2.7648    1630.9362       783.5090 54.5996    0.4653
# 3                   2.8318    1560.5043       740.9306 54.5996    0.4559
# 4                   2.7780    1524.2324       756.8203 54.6054    0.4505
#
#    total_transactions  total_premium_products  total_holidays  is_holiday  \
# 0                  25                      25          1.0000      1.0000
# 1                2630                    2630          0.0000      0.0000
# 2                2823                    2823          0.0000      0.0000
# 3                2782                    2782          0.0000      0.0000
# 4                1842                    1842          0.0000      0.0000
#
#    total_special_sale_days  is_special_sale_day  total_pay_days  is_pay_day  \
# 0                   0.0000               0.0000          1.0000      1.0000
# 1                   0.0000               0.0000          0.0000      0.0000
# 2                   2.0000               1.0000          1.0000      1.0000
# 3                   0.0000               0.0000          0.0000      0.0000
# 4                   0.0000               0.0000          1.0000      1.0000
#
#    Binoculars  CameraAccessory  CameraBag  CameraBattery  \
# 0           1                1          2              4
# 1         193               45        328            735
# 2         247               30        351            770
# 3         209               44        284            812
# 4         144               41        175            516
#
#    CameraBatteryCharger  CameraBatteryGrip  CameraEyeCup  CameraFilmRolls  \
# 0                     1                  0             0                0
# 1                   224                 11             0                0
# 2                   228                  5             0                0
# 3                   270                  9             0                0
# 4                   194                  8             0                0
#
#    CameraHousing  CameraMicrophone  CameraMount  CameraRemoteControl  \
# 0              0                 0            0                    1
# 1              0                 0            4                  141
# 2              0                 0           11                  145
# 3              0                 0            7                  108
# 4              0                 0            2                   82
#
#    CameraTripod  ExtensionTube  Filter  Flash  FlashShoeAdapter  Lens  \
# 0            13              0       0      0                 0     2
# 1           433              0     226     17                 0   366
# 2           491              0     188     23                 0   382
# 3           457              0     194     18                 0   423
# 4           363              0     112     26                 0   233
#
#    ReflectorUmbrella  Softbox  Strap  Telescope
# 0                  0        0      0          0
# 1                  0        0     13         16
# 2                  0        0     24         22
# 3                  0        0     23         30
# 4                  0        0     23         13

# %%
df.columns
# Out:
# Index(['order_week', 'Month', 'Year', 'adStock_Traditional Marketing',
#        'adStock_Digital Marketing', 'adStock_Partnership Marketing',
#        'adStock_Other Marketing', 'gmv', 'units', 'sla',
#        'product_procurement_sla', 'product_mrp', 'selling_price', 'NPS',
#        'discount', 'total_transactions', 'total_premium_products',
#        'total_holidays', 'is_holiday', 'total_special_sale_days',
#        'is_special_sale_day', 'total_pay_days', 'is_pay_day', 'Binoculars',
#        'CameraAccessory', 'CameraBag', 'CameraBattery', 'CameraBatteryCharger',
#        'CameraBatteryGrip', 'CameraEyeCup', 'CameraFilmRolls', 'CameraHousing',
#        'CameraMicrophone', 'CameraMount', 'CameraRemoteControl',
#        'CameraTripod', 'ExtensionTube', 'Filter', 'Flash', 'FlashShoeAdapter',
#        'Lens', 'ReflectorUmbrella', 'Softbox', 'Strap', 'Telescope'],
#       dtype='object')

# %%
df = df.drop(['selling_price', 'units', 'product_mrp', 'total_transactions', 'order_week', 
'is_holiday', 'is_special_sale_day', 'is_pay_day', 'Month', 'Year'], axis=1)

df.columns
# Out:
# Index(['adStock_Traditional Marketing', 'adStock_Digital Marketing',
#        'adStock_Partnership Marketing', 'adStock_Other Marketing', 'gmv',
#        'sla', 'product_procurement_sla', 'NPS', 'discount',
#        'total_premium_products', 'total_holidays', 'total_special_sale_days',
#        'total_pay_days', 'Binoculars', 'CameraAccessory', 'CameraBag',
#        'CameraBattery', 'CameraBatteryCharger', 'CameraBatteryGrip',
#        'CameraEyeCup', 'CameraFilmRolls', 'CameraHousing', 'CameraMicrophone',
#        'CameraMount', 'CameraRemoteControl', 'CameraTripod', 'ExtensionTube',
#        'Filter', 'Flash', 'FlashShoeAdapter', 'Lens', 'ReflectorUmbrella',
#        'Softbox', 'Strap', 'Telescope'],
#       dtype='object')

# %%
df.shape
# Out:
# (52, 35)

# %% [markdown]
# # Split the Data

# %%
df_train, df_test = train_test_split(df, train_size=0.8, test_size=0.2, random_state=10)

# pop the target variable
y_train = df_train.pop('gmv')
X_train = df_train
y_test = df_test.pop('gmv')
X_test = df_test

# %%
X_train.head()
# Out:
#     adStock_Traditional Marketing  adStock_Digital Marketing  \
# 6                          0.8853                     2.2013
# 41                        14.6191                    10.6456
# 2                          3.5764                     4.1648
# 42                        14.5262                    10.6515
# 34                        17.2051                    11.0268
#
#     adStock_Partnership Marketing  adStock_Other Marketing    sla  \
# 6                          0.9328                   0.0000 6.0000
# 41                        14.8309                   0.0997 4.7826
# 2                          3.7320                   0.0000 6.4913
# 42                        14.7665                   0.0000 6.4079
# 34                        16.4740                   4.7837 6.1401
#
#     product_procurement_sla     NPS  discount  total_premium_products  \
# 6                    1.0000 59.9871    0.8500                       1
# 41                   2.5144 51.8276    0.5485                    2323
# 2                    2.7648 54.5996    0.4653                    2823
# 42                   2.5532 51.4669    0.5595                    8372
# 34                   2.5374 49.2259    0.4987                    4888
#
#     total_holidays  total_special_sale_days  total_pay_days  Binoculars  \
# 6           0.0000                   2.0000          1.0000           0
# 41          0.0000                   0.0000          0.0000         181
# 2           0.0000                   2.0000          1.0000         247
# 42          0.0000                   0.0000          1.0000         513
# 34          0.0000                   0.0000          1.0000         214
#
#     CameraAccessory  CameraBag  CameraBattery  CameraBatteryCharger  \
# 6                 0          0              0                     0
# 41               15        191            328                   162
# 2                30        351            770                   228
# 42               40        640           1338                   656
# 34               50        276            973                   533
#
#     CameraBatteryGrip  CameraEyeCup  CameraFilmRolls  CameraHousing  \
# 6                   0             0                0              0
# 41                  1             3               32              0
# 2                   5             0                0              0
# 42                 10            10               79              2
# 34                  8             1               28              0
#
#     CameraMicrophone  CameraMount  CameraRemoteControl  CameraTripod  \
# 6                  0            0                    0             1
# 41                 1            6                   40           315
# 2                  0           11                  145           491
# 42                 3           38                  151          1047
# 34                 6           45                  118           571
#
#     ExtensionTube  Filter  Flash  FlashShoeAdapter  Lens  ReflectorUmbrella  \
# 6               0       0      0                 0     0                  0
# 41              1     125    657                 1   261                  0
# 2               0     188     23                 0   382                  0
# 42              3     435   2578                 0   847                  0
# 34              4     259   1410                 1   392                  0
#
#     Softbox  Strap  Telescope
# 6         0      0          0
# 41        1     29         11
# 2         0     24         22
# 42        1     73         77
# 34        0     46         44

# %% [markdown]
# # Data Scaling on Explainer Variables & Log Transformation on Target Variable

# %%
df.head(5)
# Out:
#    adStock_Traditional Marketing  adStock_Digital Marketing  \
# 0                         2.8611                     3.3318
# 1                         3.3379                     3.8872
# 2                         3.5764                     4.1648
# 3                         3.6956                     4.3036
# 4                         3.7552                     4.3730
#
#    adStock_Partnership Marketing  adStock_Other Marketing          gmv    sla  \
# 0                         2.9856                   0.0000   15375.0000 2.2800
# 1                         3.4832                   0.0000 2019042.0000 7.1563
# 2                         3.7320                   0.0000 2249245.0000 6.4913
# 3                         3.8564                   0.0000 2105858.0000 6.4881
# 4                         3.9186                   0.0000 1426134.0000 6.4707
#
#    product_procurement_sla     NPS  discount  total_premium_products  \
# 0                   2.9600 54.5996    0.5256                      25
# 1                   2.7426 54.5996    0.4622                    2630
# 2                   2.7648 54.5996    0.4653                    2823
# 3                   2.8318 54.5996    0.4559                    2782
# 4                   2.7780 54.6054    0.4505                    1842
#
#    total_holidays  total_special_sale_days  total_pay_days  Binoculars  \
# 0          1.0000                   0.0000          1.0000           1
# 1          0.0000                   0.0000          0.0000         193
# 2          0.0000                   2.0000          1.0000         247
# 3          0.0000                   0.0000          0.0000         209
# 4          0.0000                   0.0000          1.0000         144
#
#    CameraAccessory  CameraBag  CameraBattery  CameraBatteryCharger  \
# 0                1          2              4                     1
# 1               45        328            735                   224
# 2               30        351            770                   228
# 3               44        284            812                   270
# 4               41        175            516                   194
#
#    CameraBatteryGrip  CameraEyeCup  CameraFilmRolls  CameraHousing  \
# 0                  0             0                0              0
# 1                 11             0                0              0
# 2                  5             0                0              0
# 3                  9             0                0              0
# 4                  8             0                0              0
#
#    CameraMicrophone  CameraMount  CameraRemoteControl  CameraTripod  \
# 0                 0            0                    1            13
# 1                 0            4                  141           433
# 2                 0           11                  145           491
# 3                 0            7                  108           457
# 4                 0            2                   82           363
#
#    ExtensionTube  Filter  Flash  FlashShoeAdapter  Lens  ReflectorUmbrella  \
# 0              0       0      0                 0     2                  0
# 1              0     226     17                 0   366                  0
# 2              0     188     23                 0   382                  0
# 3              0     194     18                 0   423                  0
# 4              0     112     26                 0   233                  0
#
#    Softbox  Strap  Telescope
# 0        0      0          0
# 1        0     13         16
# 2        0     24         22
# 3        0     23         30
# 4        0     23         13

# %%
# Look at Value Counts of the Last 20 columns to identify any categorial variables
for col in df.columns[-21:]:
    print(f"\nValue Counts for '{col}':")
    print(df[col].value_counts())
    print("-"*50)
# Out:
# Value Counts for 'CameraAccessory':
# CameraAccessory
# 41    4
# 40    4
# 36    4
# 0     3
# 33    2
# 22    2
# 47    2
# 35    2
# 34    2
# 50    2
# 27    2
# 42    1
# 24    1
# 29    1
# 1     1
# 21    1
# 25    1
# 59    1
# 15    1
# 38    1
# 31    1
# 56    1
# 19    1
# 49    1
# 26    1
# 45    1
# 32    1
# 28    1
# 64    1
# 43    1
# 48    1
# 44    1
# 30    1
# 37    1
# Name: count, dtype: int64
# --------------------------------------------------
#
# Value Counts for 'CameraBag':
# CameraBag
# 0      3
# 317    2
# 284    2
# 265    2
# 2      1
# 295    1
# 300    1
# 313    1
# 276    1
# 347    1
# 272    1
# 280    1
# 318    1
# 191    1
# 273    1
# 312    1
# 640    1
# 427    1
# 440    1
# 430    1
# 531    1
# 388    1
# 352    1
# 365    1
# 331    1
# 249    1
# 274    1
# 879    1
# 351    1
# 175    1
# 241    1
# 266    1
# 261    1
# 231    1
# 211    1
# 219    1
# 275    1
# 328    1
# 320    1
# 307    1
# 296    1
# 216    1
# 259    1
# 322    1
# 303    1
# 285    1
# 196    1
# Name: count, dtype: int64
# --------------------------------------------------
#
# Value Counts for 'CameraBattery':
# CameraBattery
# 0       3
# 630     2
# 697     2
# 4       1
# 796     1
# 859     1
# 1528    1
# 834     1
# 973     1
# 1145    1
# 672     1
# 1103    1
# 1140    1
# 1338    1
# 328     1
# 604     1
# 762     1
# 738     1
# 758     1
# 815     1
# 684     1
# 662     1
# 608     1
# 479     1
# 1000    1
# 451     1
# 593     1
# 735     1
# 770     1
# 812     1
# 516     1
# 789     1
# 785     1
# 646     1
# 616     1
# 1424    1
# 602     1
# 703     1
# 637     1
# 649     1
# 543     1
# 635     1
# 757     1
# 664     1
# 713     1
# 641     1
# 556     1
# 253     1
# Name: count, dtype: int64
# --------------------------------------------------
#
# Value Counts for 'CameraBatteryCharger':
# CameraBatteryCharger
# 224    4
# 0      3
# 232    2
# 215    2
# 216    2
# 199    2
# 1      1
# 279    1
# 498    1
# 589    1
# 353    1
# 276    1
# 162    1
# 656    1
# 533    1
# 387    1
# 380    1
# 390    1
# 418    1
# 329    1
# 307    1
# 303    1
# 221    1
# 472    1
# 208    1
# 304    1
# 644    1
# 228    1
# 270    1
# 194    1
# 169    1
# 167    1
# 175    1
# 172    1
# 184    1
# 423    1
# 210    1
# 179    1
# 238    1
# 206    1
# 245    1
# 295    1
# 151    1
# Name: count, dtype: int64
# --------------------------------------------------
#
# Value Counts for 'CameraBatteryGrip':
# CameraBatteryGrip
# 10    6
# 4     6
# 3     6
# 9     5
# 0     4
# 11    4
# 5     4
# 2     4
# 8     3
# 7     3
# 12    2
# 6     2
# 15    1
# 17    1
# 1     1
# Name: count, dtype: int64
# --------------------------------------------------
#
# Value Counts for 'CameraEyeCup':
# CameraEyeCup
# 0     24
# 1      8
# 2      6
# 3      5
# 4      3
# 5      2
# 10     2
# 7      1
# 12     1
# Name: count, dtype: int64
# --------------------------------------------------
#
# Value Counts for 'CameraFilmRolls':
# CameraFilmRolls
# 0      8
# 39     4
# 23     3
# 41     3
# 28     2
# 79     2
# 49     2
# 53     2
# 18     2
# 44     2
# 32     2
# 33     2
# 31     2
# 48     1
# 119    1
# 109    1
# 107    1
# 89     1
# 61     1
# 13     1
# 16     1
# 38     1
# 42     1
# 30     1
# 40     1
# 29     1
# 36     1
# 22     1
# 82     1
# Name: count, dtype: int64
# --------------------------------------------------
#
# Value Counts for 'CameraHousing':
# CameraHousing
# 0    42
# 2     5
# 1     4
# 5     1
# Name: count, dtype: int64
# --------------------------------------------------
#
# Value Counts for 'CameraMicrophone':
# CameraMicrophone
# 0    35
# 1     6
# 2     4
# 6     3
# 5     2
# 7     1
# 3     1
# Name: count, dtype: int64
# --------------------------------------------------
#
# Value Counts for 'CameraMount':
# CameraMount
# 0     4
# 14    4
# 11    3
# 15    3
# 23    3
# 12    3
# 13    3
# 21    2
# 27    2
# 4     2
# 24    2
# 2     2
# 7     2
# 8     2
# 18    1
# 31    1
# 10    1
# 19    1
# 17    1
# 38    1
# 6     1
# 25    1
# 39    1
# 45    1
# 51    1
# 52    1
# 34    1
# 20    1
# 5     1
# Name: count, dtype: int64
# --------------------------------------------------
#
# Value Counts for 'CameraRemoteControl':
# CameraRemoteControl
# 108    3
# 0      3
# 137    3
# 112    3
# 82     2
# 131    2
# 136    2
# 1      1
# 70     1
# 118    1
# 134    1
# 100    1
# 101    1
# 117    1
# 88     1
# 103    1
# 40     1
# 151    1
# 77     1
# 91     1
# 116    1
# 89     1
# 67     1
# 86     1
# 87     1
# 64     1
# 79     1
# 75     1
# 141    1
# 95     1
# 81     1
# 104    1
# 127    1
# 114    1
# 165    1
# 309    1
# 113    1
# 159    1
# 121    1
# 145    1
# 22     1
# Name: count, dtype: int64
# --------------------------------------------------
#
# Value Counts for 'CameraTripod':
# CameraTripod
# 1       2
# 13      1
# 738     1
# 373     1
# 565     1
# 484     1
# 762     1
# 755     1
# 571     1
# 622     1
# 554     1
# 486     1
# 561     1
# 440     1
# 578     1
# 315     1
# 1047    1
# 638     1
# 615     1
# 423     1
# 499     1
# 325     1
# 227     1
# 249     1
# 173     1
# 424     1
# 786     1
# 433     1
# 672     1
# 491     1
# 457     1
# 363     1
# 0       1
# 549     1
# 778     1
# 618     1
# 878     1
# 2319    1
# 832     1
# 2348    1
# 597     1
# 758     1
# 791     1
# 676     1
# 666     1
# 526     1
# 715     1
# 1185    1
# 558     1
# 745     1
# 88      1
# Name: count, dtype: int64
# --------------------------------------------------
#
# Value Counts for 'ExtensionTube':
# ExtensionTube
# 0    28
# 3     7
# 2     5
# 1     4
# 4     4
# 6     2
# 5     2
# Name: count, dtype: int64
# --------------------------------------------------
#
# Value Counts for 'Filter':
# Filter
# 0      4
# 188    2
# 226    2
# 225    2
# 208    2
# 253    2
# 221    2
# 234    1
# 211    1
# 259    1
# 325    1
# 228    1
# 175    1
# 125    1
# 192    1
# 205    1
# 435    1
# 230    1
# 232    1
# 279    1
# 240    1
# 218    1
# 187    1
# 242    1
# 305    1
# 268    1
# 255    1
# 194    1
# 112    1
# 190    1
# 263    1
# 213    1
# 214    1
# 191    1
# 952    1
# 238    1
# 292    1
# 251    1
# 284    1
# 193    1
# 227    1
# 185    1
# 109    1
# Name: count, dtype: int64
# --------------------------------------------------
#
# Value Counts for 'Flash':
# Flash
# 0       4
# 1870    1
# 1911    1
# 710     1
# 1586    1
# 2030    1
# 1410    1
# 1519    1
# 1495    1
# 1287    1
# 1449    1
# 1568    1
# 1316    1
# 657     1
# 2578    1
# 2151    1
# 1944    1
# 1591    1
# 2003    1
# 1795    1
# 2309    1
# 1434    1
# 861     1
# 641     1
# 1099    1
# 17      1
# 2036    1
# 23      1
# 18      1
# 26      1
# 179     1
# 192     1
# 241     1
# 136     1
# 142     1
# 164     1
# 1140    1
# 184     1
# 937     1
# 1293    1
# 573     1
# 299     1
# 266     1
# 265     1
# 273     1
# 322     1
# 711     1
# 832     1
# 520     1
# Name: count, dtype: int64
# --------------------------------------------------
#
# Value Counts for 'FlashShoeAdapter':
# FlashShoeAdapter
# 0    50
# 1     2
# Name: count, dtype: int64
# --------------------------------------------------
#
# Value Counts for 'Lens':
# Lens
# 473     2
# 0       2
# 326     2
# 527     1
# 516     1
# 433     1
# 438     1
# 389     1
# 429     1
# 378     1
# 392     1
# 467     1
# 367     1
# 411     1
# 2       1
# 363     1
# 847     1
# 526     1
# 598     1
# 556     1
# 733     1
# 698     1
# 685     1
# 785     1
# 507     1
# 261     1
# 479     1
# 366     1
# 533     1
# 382     1
# 423     1
# 233     1
# 3       1
# 314     1
# 327     1
# 380     1
# 379     1
# 354     1
# 1597    1
# 427     1
# 515     1
# 446     1
# 508     1
# 324     1
# 355     1
# 425     1
# 436     1
# 408     1
# 280     1
# Name: count, dtype: int64
# --------------------------------------------------
#
# Value Counts for 'ReflectorUmbrella':
# ReflectorUmbrella
# 0    50
# 1     1
# 3     1
# Name: count, dtype: int64
# --------------------------------------------------
#
# Value Counts for 'Softbox':
# Softbox
# 0    41
# 1     9
# 4     1
# 2     1
# Name: count, dtype: int64
# --------------------------------------------------
#
# Value Counts for 'Strap':
# Strap
# 42    5
# 29    5
# 0     4
# 23    4
# 28    3
# 43    2
# 35    2
# 46    2
# 13    2
# 26    2
# 36    2
# 25    2
# 20    2
# 24    2
# 22    1
# 21    1
# 37    1
# 33    1
# 14    1
# 19    1
# 31    1
# 38    1
# 44    1
# 73    1
# 55    1
# 48    1
# 40    1
# Name: count, dtype: int64
# --------------------------------------------------
#
# Value Counts for 'Telescope':
# Telescope
# 0     4
# 44    3
# 22    3
# 43    3
# 16    3
# 38    2
# 37    2
# 14    2
# 47    2
# 26    2
# 31    2
# 25    2
# 66    1
# 77    1
# 11    1
# 46    1
# 42    1
# 50    1
# 51    1
# 49    1
# 69    1
# 41    1
# 39    1
# 29    1
# 34    1
# 40    1
# 27    1
# 24    1
# 17    1
# 20    1
# 33    1
# 13    1
# 30    1
# 63    1
# Name: count, dtype: int64
# --------------------------------------------------

# %%
# Define categorical variables that should remain unchanged
cat_columns = ['FlashShoeAdapter', 'ReflectorUmbrella']

# Identify numerical columns (excluding categorical)
num_cols = [col for col in X_train.columns if col not in cat_columns]

# Apply StandardScaler only on numerical columns
scaler = StandardScaler()
X_train_scaled_num = scaler.fit_transform(X_train[num_cols])  # Fit on train
X_test_scaled_num = scaler.transform(X_test[num_cols])  # Transform test

# Convert scaled arrays back into DataFrames
X_train_scaled_df = pd.DataFrame(X_train_scaled_num, columns=num_cols, index=X_train.index)
X_test_scaled_df = pd.DataFrame(X_test_scaled_num, columns=num_cols, index=X_test.index)

# Keep categorical variables unchanged
X_train_cat_df = X_train[cat_columns].copy()
X_test_cat_df = X_test[cat_columns].copy()

# Reconstruct final DataFrame with both scaled numerical and unchanged categorical features
X_train_final_scaled = pd.concat([X_train_scaled_df, X_train_cat_df], axis=1)
X_test_final_scaled = pd.concat([X_test_scaled_df, X_test_cat_df], axis=1)

# Ensure test dataset column order matches train dataset
X_test_final_scaled = X_test_final_scaled[X_train_final_scaled.columns]

print("✅ Scaling completed successfully!")
# Out:
# ✅ Scaling completed successfully!

# %%
# Log Transformation on Y
# y_train = np.log(y_train)
# y_test = np.log(y_test)

# %% [markdown]
# # Recursive Feature Elimination

# %%
def perform_rfe_cv(X_train, y_train, X_test, num_features=20, cv_folds=5):
    """
    Perform Recursive Feature Elimination with Cross-Validation (RFE-CV) 
    to select the optimal number of features, then enforce a fixed selection.

    Parameters:
    - X_train (DataFrame): Training feature set
    - y_train (Series): Training target variable
    - X_test (DataFrame): Test feature set
    - num_features (int): Number of features to retain
    - cv_folds (int): Number of cross-validation folds

    Returns:
    - X_train_selected (DataFrame): Transformed X_train with selected features
    - X_test_selected (DataFrame): Transformed X_test with selected features
    - selected_features (list): List of selected feature names
    """
    print(f"Running RFE-CV to determine important features...")

    model = LinearRegression()  
    rfecv = RFECV(estimator=model, step=1, cv=KFold(n_splits=cv_folds), scoring="r2", n_jobs=-1)
    
    # Fit RFECV model
    rfecv.fit(X_train, y_train)

    # Get initially selected features
    initial_selected_features = X_train.columns[rfecv.support_]
    print(f"RFECV Selected Features ({len(initial_selected_features)}): {list(initial_selected_features)}")

    # **Ensure we get exactly `num_features` using RFE**
    if len(initial_selected_features) > num_features or len(initial_selected_features) < num_features:
        print(f"\nRefining selection to exactly {num_features} features using RFE...")
        rfe = RFE(estimator=model, n_features_to_select=num_features)
        rfe.fit(X_train, y_train)
        selected_features = X_train.columns[rfe.support_]
    else:
        selected_features = initial_selected_features

    print(f"Final Selected Features ({len(selected_features)}): {list(selected_features)}")

    # Transform datasets
    X_train_selected = X_train[selected_features]
    X_test_selected = X_test[selected_features]

    return X_train_selected, X_test_selected, selected_features

# %%
# Run RFE with CV to select exactly 25 best features
X_train_rfe, X_test_rfe, selected_features = perform_rfe_cv(
    X_train_final_scaled, y_train, X_test_final_scaled, num_features=25, cv_folds=5
)
# Out:
# Running RFE-CV to determine important features...
# RFECV Selected Features (4): ['adStock_Traditional Marketing', 'total_premium_products', 'CameraBatteryGrip', 'Filter']
#
# Refining selection to exactly 25 features using RFE...
# Final Selected Features (25): ['adStock_Traditional Marketing', 'adStock_Digital Marketing', 'adStock_Partnership Marketing', 'adStock_Other Marketing', 'NPS', 'total_premium_products', 'total_pay_days', 'Binoculars', 'CameraAccessory', 'CameraBag', 'CameraBattery', 'CameraBatteryCharger', 'CameraBatteryGrip', 'CameraEyeCup', 'CameraHousing', 'CameraMicrophone', 'CameraMount', 'CameraRemoteControl', 'CameraTripod', 'ExtensionTube', 'Filter', 'Flash', 'Lens', 'Strap', 'ReflectorUmbrella']

# %% [markdown]
# # Model Training Function

# %%
def train_base_model(X_train, y_train):
    """
    Builds and logs the base OLS model before feature elimination starts.

    Parameters:
    - X_train (DataFrame): Training feature set with selected features.
    - y_train (Series): Training target variable.

    Returns:
    - model (statsmodels OLS): Trained OLS model.
    - X_train (DataFrame): Transformed X_train with selected features.
    """
    mlflow.set_experiment("MMM_Modeling_Camera")

    # Ensure previous MLflow runs are properly closed
    if mlflow.active_run():
        mlflow.end_run()

    with mlflow.start_run():
        print("\n========== Building Initial Base Model ==========")

        # Add constant for OLS regression
        X_train_lm = sm.add_constant(X_train)
        model = sm.OLS(y_train, X_train_lm).fit()

        # Print Model Summary
        print(f"\n========== Model Summary ==========")
        print(model.summary())

        # Compute VIF values
        vif_data = pd.DataFrame()
        vif_data["Feature"] = X_train.columns
        vif_data["VIF"] = [variance_inflation_factor(X_train.values, i) for i in range(X_train.shape[1])]
        vif_data = vif_data.sort_values(by="VIF", ascending=False)

        print("\n========== Variance Inflation Factor (VIF) ==========")
        print(vif_data)

        # Log Model Details to MLflow
        mlflow.log_param("Base Model Features", list(X_train.columns))
        mlflow.log_metric("Base Model R²", model.rsquared)
        mlflow.statsmodels.log_model(model, "Base_Model")

        # Ensure MLflow run is properly closed
        mlflow.end_run()

    return model, X_train

# %%
# Train base model using the selected 25 features from RFE
base_model, X_train_base = train_base_model(X_train_rfe, y_train)
# Out:
# ========== Building Initial Base Model ==========
#
# ========== Model Summary ==========
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    gmv   R-squared:                       0.996
# Model:                            OLS   Adj. R-squared:                  0.989
# Method:                 Least Squares   F-statistic:                     151.2
# Date:                Mon, 17 Mar 2025   Prob (F-statistic):           5.76e-14
# Time:                        02:01:39   Log-Likelihood:                -515.38
# No. Observations:                  41   AIC:                             1083.
# Df Residuals:                      15   BIC:                             1127.
# Df Model:                          25
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# const                          2.511e+06   1.95e+04    128.892      0.000    2.47e+06    2.55e+06
# adStock_Traditional Marketing -9.324e+05   9.77e+05     -0.954      0.355   -3.02e+06    1.15e+06
# adStock_Digital Marketing      -4.17e+04   6.78e+04     -0.615      0.548   -1.86e+05    1.03e+05
# adStock_Partnership Marketing  9.397e+05   1.02e+06      0.921      0.372   -1.23e+06    3.11e+06
# adStock_Other Marketing        1.384e+05   6.31e+04      2.192      0.045    3798.036    2.73e+05
# NPS                           -4.047e+04   5.31e+04     -0.763      0.458   -1.54e+05    7.26e+04
# total_premium_products        -5.432e+06   3.35e+06     -1.622      0.126   -1.26e+07     1.7e+06
# total_pay_days                -4.355e+04   2.57e+04     -1.692      0.111   -9.84e+04    1.13e+04
# Binoculars                     5.648e+05    2.3e+05      2.460      0.027    7.54e+04    1.05e+06
# CameraAccessory                -7.32e+04   4.66e+04     -1.570      0.137   -1.73e+05    2.62e+04
# CameraBag                      4.351e+05   3.02e+05      1.442      0.170   -2.08e+05    1.08e+06
# CameraBattery                  1.007e+06   5.01e+05      2.012      0.063   -5.99e+04    2.07e+06
# CameraBatteryCharger           4.934e+05   2.97e+05      1.663      0.117   -1.39e+05    1.13e+06
# CameraBatteryGrip              9.503e+04   3.58e+04      2.657      0.018    1.88e+04    1.71e+05
# CameraEyeCup                   7.504e+04   4.55e+04      1.651      0.120   -2.18e+04    1.72e+05
# CameraHousing                   8.17e+04   6.92e+04      1.181      0.256   -6.57e+04    2.29e+05
# CameraMicrophone              -6.489e+04   6.63e+04     -0.979      0.343   -2.06e+05    7.64e+04
# CameraMount                    1.503e+05   9.94e+04      1.512      0.151   -6.16e+04    3.62e+05
# CameraRemoteControl            2.824e+05   1.34e+05      2.101      0.053   -4045.399    5.69e+05
# CameraTripod                   1.555e+06   8.39e+05      1.853      0.084   -2.34e+05    3.34e+06
# ExtensionTube                  5.544e+04   7.42e+04      0.747      0.467   -1.03e+05    2.14e+05
# Filter                         4.977e+05   1.84e+05      2.699      0.016    1.05e+05    8.91e+05
# Flash                          2.421e+06   1.38e+06      1.749      0.101   -5.29e+05    5.37e+06
# Lens                           8.561e+05   5.64e+05      1.519      0.150   -3.45e+05    2.06e+06
# Strap                          8.556e+04   7.53e+04      1.137      0.273   -7.48e+04    2.46e+05
# ReflectorUmbrella             -4.122e+04   7.67e+04     -0.537      0.599   -2.05e+05    1.22e+05
# ==============================================================================
# Omnibus:                        7.882   Durbin-Watson:                   1.848
# Prob(Omnibus):                  0.019   Jarque-Bera (JB):                6.701
# Skew:                           0.917   Prob(JB):                       0.0351
# Kurtosis:                       3.749   Cond. No.                         695.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ========== Variance Inflation Factor (VIF) ==========
#                           Feature        VIF
# 5          total_premium_products 34487.3649
# 21                          Flash  5900.2625
# 2   adStock_Partnership Marketing  3066.0723
# 0   adStock_Traditional Marketing  2805.1241
# 18                   CameraTripod  2167.7662
# 22                           Lens   961.8464
# 10                  CameraBattery   766.0476
# 9                       CameraBag   279.4243
# 11           CameraBatteryCharger   269.1834
# 7                      Binoculars   161.5594
# 20                         Filter   104.8864
# 17            CameraRemoteControl    55.6513
# 16                    CameraMount    30.0144
# 23                          Strap    17.5050
# 19                  ExtensionTube    16.5144
# 14                  CameraHousing    14.7771
# 1       adStock_Digital Marketing    14.0955
# 15               CameraMicrophone    13.5850
# 3         adStock_Other Marketing    12.1588
# 4                             NPS     8.6534
# 8                 CameraAccessory     6.7040
# 13                   CameraEyeCup     6.3276
# 12              CameraBatteryGrip     3.9435
# 24              ReflectorUmbrella     3.7851
# 6                  total_pay_days     2.0106
# 2025/03/17 02:01:43 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.

# %% [markdown]
# ## Try to get a more Stable Model using Backward Elimination

# %%
def train_optimized_model(X_train, y_train, X_test, y_test, max_iterations=10, vif_threshold=100, p_value_threshold=0.05):
    """
    Step 1: Eliminates features based on VIF until all values are ≤ 100.
    Step 2: Builds the model and iteratively removes high p-value features.
    Logs each iteration to MLflow.
    """
    mlflow.set_experiment("MMM_Modeling")

    # Ensure previous MLflow runs are properly closed
    if mlflow.active_run():
        mlflow.end_run()

    with mlflow.start_run():
        eliminated_features = []
        
        ### **Step 1: Remove High VIF Features Before Modeling**
        print("\n========== Eliminating High VIF Features Before Modeling ==========")
        while True:
            # Compute VIF
            vif_data = pd.DataFrame()
            vif_data["Feature"] = X_train.columns
            vif_data["VIF"] = [variance_inflation_factor(X_train.values, i) for i in range(X_train.shape[1])]
            vif_data = vif_data.sort_values(by="VIF", ascending=False)

            print(f"\nVIF Before Modeling:")
            print(vif_data)

            # Check if the highest VIF is still above the threshold
            if vif_data["VIF"].max() > vif_threshold:
                high_vif_feature = vif_data.iloc[0]["Feature"]
                print(f"Removing {high_vif_feature} due to very high VIF ({vif_data.iloc[0]['VIF']:.2f})")
                eliminated_features.append(high_vif_feature)  # Track removed features
                X_train = X_train.drop(columns=[high_vif_feature])
            else:
                print("All VIF values are now below the threshold. Proceeding to modeling.")
                break  # Stop when all VIF values are ≤ threshold

        ### **Step 2: Start Modeling and Eliminate High p-value Features**
        iteration = 1
        while iteration <= max_iterations:
            print(f"\n========== Iteration {iteration}: Training Model ==========")

            # Fit OLS Model
            X_train_lm = sm.add_constant(X_train)
            model = sm.OLS(y_train, X_train_lm).fit()

            # Print Model Summary
            print(f"\nModel Summary (Iteration {iteration}):")
            print(model.summary())

            # Compute VIF
            vif_data = pd.DataFrame()
            vif_data["Feature"] = X_train.columns
            vif_data["VIF"] = [variance_inflation_factor(X_train.values, i) for i in range(X_train.shape[1])]
            vif_data = vif_data.sort_values(by="VIF", ascending=False)

            print(f"\nVIF Values (Iteration {iteration}):")
            print(vif_data)

            feature_removed = False  # Track if any feature was removed

            # **Step 2: Eliminate the Highest p-value Feature**
            p_values = model.pvalues.drop("const", errors="ignore")
            max_p_feature = p_values.idxmax()
            max_p_value = p_values.max()

            if max_p_value > p_value_threshold:
                if max_p_feature in X_train.columns:
                    print(f"Removing {max_p_feature} due to high p-value ({max_p_value:.4f})")
                    eliminated_features.append(max_p_feature)
                    X_train = X_train.drop(columns=[max_p_feature])
                    feature_removed = True
            else:
                print("No high p-value features remaining.")

            # **If no features were removed, stop the process**
            if not feature_removed:
                print("\nNo more features to remove. Stopping.")
                break

            iteration += 1

        # Final Model
        final_model = sm.OLS(y_train, sm.add_constant(X_train)).fit()
        print(f"\n========== Final Model Summary ==========")
        print(final_model.summary())

        # Print final VIF values
        final_vif_data = pd.DataFrame()
        final_vif_data["Feature"] = X_train.columns
        final_vif_data["VIF"] = [variance_inflation_factor(X_train.values, i) for i in range(X_train.shape[1])]
        final_vif_data = final_vif_data.sort_values(by="VIF", ascending=False)

        print(f"\n========== Final VIF Values ==========")
        print(final_vif_data)

        # Ensure X_test matches selected features in X_train
        X_test_final = X_test[X_train.columns]
        X_test_final = sm.add_constant(X_test_final)

        # Predictions
        y_test_pred = final_model.predict(X_test_final)
        r2 = r2_score(y_test, y_test_pred)

        # Log to MLflow
        mlflow.log_param("Eliminated Features", eliminated_features)
        mlflow.log_param("Final Model Features", list(X_train.columns))
        mlflow.log_metric("Final R-squared", r2)
        mlflow.sklearn.log_model(final_model, "Final_Model")

        # Ensure MLflow run is properly closed
        mlflow.end_run()

        return final_model, X_train

# %%
final_model, X_train_final = train_optimized_model(X_train_rfe,
                                                   y_train,
                                                   X_test_rfe,
                                                   y_test,
                                                   max_iterations=12,
                                                   vif_threshold=100)
# Out:
# ========== Eliminating High VIF Features Before Modeling ==========
#
# VIF Before Modeling:
#                           Feature        VIF
# 5          total_premium_products 34487.3649
# 21                          Flash  5900.2625
# 2   adStock_Partnership Marketing  3066.0723
# 0   adStock_Traditional Marketing  2805.1241
# 18                   CameraTripod  2167.7662
# 22                           Lens   961.8464
# 10                  CameraBattery   766.0476
# 9                       CameraBag   279.4243
# 11           CameraBatteryCharger   269.1834
# 7                      Binoculars   161.5594
# 20                         Filter   104.8864
# 17            CameraRemoteControl    55.6513
# 16                    CameraMount    30.0144
# 23                          Strap    17.5050
# 19                  ExtensionTube    16.5144
# 14                  CameraHousing    14.7771
# 1       adStock_Digital Marketing    14.0955
# 15               CameraMicrophone    13.5850
# 3         adStock_Other Marketing    12.1588
# 4                             NPS     8.6534
# 8                 CameraAccessory     6.7040
# 13                   CameraEyeCup     6.3276
# 12              CameraBatteryGrip     3.9435
# 24              ReflectorUmbrella     3.7851
# 6                  total_pay_days     2.0106
# Removing total_premium_products due to very high VIF (34487.36)
#
# VIF Before Modeling:
#                           Feature       VIF
# 2   adStock_Partnership Marketing 2399.9846
# 0   adStock_Traditional Marketing 2231.4403
# 8                       CameraBag  102.1366
# 21                           Lens   98.3150
# 19                         Filter   33.5566
# 10           CameraBatteryCharger   27.4026
# 9                   CameraBattery   26.6772
# 15                    CameraMount   22.5137
# 16            CameraRemoteControl   21.0081
# 20                          Flash   19.8483
# 22                          Strap   16.0066
# 18                  ExtensionTube   15.6857
# 14               CameraMicrophone   13.4765
# 13                  CameraHousing   12.7876
# 1       adStock_Digital Marketing   12.7371
# 6                      Binoculars   11.8973
# 3         adStock_Other Marketing   10.0177
# 4                             NPS    8.6532
# 12                   CameraEyeCup    5.9756
# 7                 CameraAccessory    5.6441
# 17                   CameraTripod    5.2171
# 23              ReflectorUmbrella    3.6718
# 11              CameraBatteryGrip    3.4306
# 5                  total_pay_days    2.0062
# Removing adStock_Partnership Marketing due to very high VIF (2399.98)
#
# VIF Before Modeling:
#                           Feature     VIF
# 20                           Lens 86.8204
# 7                       CameraBag 64.7298
# 18                         Filter 32.3750
# 9            CameraBatteryCharger 23.8495
# 8                   CameraBattery 22.9578
# 14                    CameraMount 22.4560
# 15            CameraRemoteControl 20.9824
# 21                          Strap 15.7558
# 17                  ExtensionTube 15.6531
# 13               CameraMicrophone 13.3399
# 19                          Flash 12.7430
# 12                  CameraHousing 12.5947
# 5                      Binoculars 10.7014
# 1       adStock_Digital Marketing 10.2433
# 0   adStock_Traditional Marketing  9.6904
# 3                             NPS  5.8125
# 11                   CameraEyeCup  5.6179
# 16                   CameraTripod  4.8428
# 6                 CameraAccessory  4.5281
# 2         adStock_Other Marketing  4.2775
# 10              CameraBatteryGrip  3.3226
# 22              ReflectorUmbrella  2.6847
# 4                  total_pay_days  1.9442
# All VIF values are now below the threshold. Proceeding to modeling.
#
# ========== Iteration 1: Training Model ==========
#
# Model Summary (Iteration 1):
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    gmv   R-squared:                       0.995
# Model:                            OLS   Adj. R-squared:                  0.989
# Method:                 Least Squares   F-statistic:                     158.1
# Date:                Mon, 17 Mar 2025   Prob (F-statistic):           1.23e-15
# Time:                        02:03:40   Log-Likelihood:                -518.73
# No. Observations:                  41   AIC:                             1085.
# Df Residuals:                      17   BIC:                             1127.
# Df Model:                          23
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# const                          2.514e+06   1.94e+04    129.745      0.000    2.47e+06    2.55e+06
# adStock_Traditional Marketing -5.298e+04   5.75e+04     -0.921      0.370   -1.74e+05    6.83e+04
# adStock_Digital Marketing     -1810.4196   5.87e+04     -0.031      0.976   -1.26e+05    1.22e+05
# adStock_Other Marketing        8.711e+04   3.81e+04      2.286      0.035    6717.701    1.67e+05
# NPS                           -4.608e+04   4.43e+04     -1.041      0.312   -1.39e+05    4.73e+04
# total_pay_days                 -4.03e+04   2.57e+04     -1.570      0.135   -9.45e+04    1.39e+04
# Binoculars                     2.026e+05      6e+04      3.377      0.004     7.6e+04    3.29e+05
# CameraAccessory               -3.956e+04   3.91e+04     -1.011      0.326   -1.22e+05     4.3e+04
# CameraBag                      7.167e+04   1.49e+05      0.482      0.636   -2.42e+05    3.86e+05
# CameraBattery                  2.029e+05   8.87e+04      2.288      0.035    1.58e+04     3.9e+05
# CameraBatteryCharger           3.092e+04   8.96e+04      0.345      0.734   -1.58e+05     2.2e+05
# CameraBatteryGrip              7.287e+04   3.34e+04      2.181      0.044    2364.753    1.43e+05
# CameraEyeCup                   5.522e+04   4.35e+04      1.270      0.221   -3.65e+04    1.47e+05
# CameraHousing                  3.959e+04   6.53e+04      0.607      0.552   -9.81e+04    1.77e+05
# CameraMicrophone              -7.557e+04    6.7e+04     -1.128      0.275   -2.17e+05    6.58e+04
# CameraMount                    6.793e+04   8.73e+04      0.778      0.447   -1.16e+05    2.52e+05
# CameraRemoteControl             1.12e+05   8.54e+04      1.311      0.207   -6.82e+04    2.92e+05
# CameraTripod                   1.971e+05   4.04e+04      4.882      0.000    1.12e+05    2.82e+05
# ExtensionTube                  3.156e+04   7.38e+04      0.428      0.674   -1.24e+05    1.87e+05
# Filter                         2.475e+05   1.04e+05      2.369      0.030    2.71e+04    4.68e+05
# Flash                           1.89e+05   6.61e+04      2.858      0.011    4.95e+04    3.29e+05
# Lens                          -2.095e+04   1.73e+05     -0.121      0.905   -3.87e+05    3.45e+05
# Strap                          5.146e+04   7.28e+04      0.707      0.489   -1.02e+05    2.05e+05
# ReflectorUmbrella             -7.197e+04   6.43e+04     -1.119      0.278   -2.08e+05    6.37e+04
# ==============================================================================
# Omnibus:                        3.219   Durbin-Watson:                   2.175
# Prob(Omnibus):                  0.200   Jarque-Bera (JB):                2.320
# Skew:                           0.572   Prob(JB):                        0.313
# Kurtosis:                       3.223   Cond. No.                         42.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# VIF Values (Iteration 1):
#                           Feature     VIF
# 20                           Lens 86.8204
# 7                       CameraBag 64.7298
# 18                         Filter 32.3750
# 9            CameraBatteryCharger 23.8495
# 8                   CameraBattery 22.9578
# 14                    CameraMount 22.4560
# 15            CameraRemoteControl 20.9824
# 21                          Strap 15.7558
# 17                  ExtensionTube 15.6531
# 13               CameraMicrophone 13.3399
# 19                          Flash 12.7430
# 12                  CameraHousing 12.5947
# 5                      Binoculars 10.7014
# 1       adStock_Digital Marketing 10.2433
# 0   adStock_Traditional Marketing  9.6904
# 3                             NPS  5.8125
# 11                   CameraEyeCup  5.6179
# 16                   CameraTripod  4.8428
# 6                 CameraAccessory  4.5281
# 2         adStock_Other Marketing  4.2775
# 10              CameraBatteryGrip  3.3226
# 22              ReflectorUmbrella  2.6847
# 4                  total_pay_days  1.9442
# Removing adStock_Digital Marketing due to high p-value (0.9757)
#
# ========== Iteration 2: Training Model ==========
#
# Model Summary (Iteration 2):
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    gmv   R-squared:                       0.995
# Model:                            OLS   Adj. R-squared:                  0.990
# Method:                 Least Squares   F-statistic:                     175.0
# Date:                Mon, 17 Mar 2025   Prob (F-statistic):           9.09e-17
# Time:                        02:03:40   Log-Likelihood:                -518.73
# No. Observations:                  41   AIC:                             1083.
# Df Residuals:                      18   BIC:                             1123.
# Df Model:                          22
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# const                          2.514e+06   1.88e+04    133.523      0.000    2.47e+06    2.55e+06
# adStock_Traditional Marketing -5.415e+04   4.19e+04     -1.293      0.213   -1.42e+05    3.39e+04
# adStock_Other Marketing        8.686e+04   3.62e+04      2.399      0.027    1.08e+04    1.63e+05
# NPS                           -4.608e+04    4.3e+04     -1.071      0.298   -1.36e+05    4.43e+04
# total_pay_days                -4.005e+04   2.37e+04     -1.691      0.108   -8.98e+04    9702.238
# Binoculars                     2.022e+05   5.68e+04      3.562      0.002    8.29e+04    3.21e+05
# CameraAccessory                -3.94e+04   3.77e+04     -1.045      0.310   -1.19e+05    3.98e+04
# CameraBag                      7.277e+04    1.4e+05      0.518      0.611   -2.22e+05    3.68e+05
# CameraBattery                  2.032e+05   8.56e+04      2.375      0.029    2.34e+04    3.83e+05
# CameraBatteryCharger           3.082e+04    8.7e+04      0.354      0.727   -1.52e+05    2.14e+05
# CameraBatteryGrip                7.3e+04   3.22e+04      2.266      0.036    5323.947    1.41e+05
# CameraEyeCup                   5.492e+04   4.12e+04      1.334      0.199   -3.16e+04    1.41e+05
# CameraHousing                  4.072e+04   5.27e+04      0.773      0.449   -6.99e+04    1.51e+05
# CameraMicrophone              -7.457e+04   5.71e+04     -1.307      0.208   -1.94e+05    4.53e+04
# CameraMount                    6.644e+04   7.06e+04      0.941      0.359   -8.19e+04    2.15e+05
# CameraRemoteControl            1.123e+05   8.23e+04      1.365      0.189   -6.06e+04    2.85e+05
# CameraTripod                   1.977e+05   3.46e+04      5.712      0.000    1.25e+05     2.7e+05
# ExtensionTube                  3.258e+04    6.4e+04      0.509      0.617   -1.02e+05    1.67e+05
# Filter                         2.475e+05   1.02e+05      2.438      0.025    3.42e+04    4.61e+05
# Flash                          1.895e+05   6.29e+04      3.013      0.007    5.73e+04    3.22e+05
# Lens                          -2.281e+04   1.58e+05     -0.144      0.887   -3.55e+05    3.09e+05
# Strap                           5.06e+04   6.54e+04      0.774      0.449   -8.68e+04    1.88e+05
# ReflectorUmbrella             -7.186e+04   6.24e+04     -1.152      0.264   -2.03e+05    5.92e+04
# ==============================================================================
# Omnibus:                        3.212   Durbin-Watson:                   2.177
# Prob(Omnibus):                  0.201   Jarque-Bera (JB):                2.309
# Skew:                           0.570   Prob(JB):                        0.315
# Kurtosis:                       3.226   Cond. No.                         38.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# VIF Values (Iteration 2):
#                           Feature     VIF
# 19                           Lens 75.8163
# 6                       CameraBag 60.8725
# 17                         Filter 32.3732
# 8            CameraBatteryCharger 23.8125
# 7                   CameraBattery 22.6502
# 14            CameraRemoteControl 20.5945
# 13                    CameraMount 15.4351
# 20                          Strap 13.4627
# 16                  ExtensionTube 12.3351
# 18                          Flash 12.1729
# 12               CameraMicrophone 10.2360
# 4                      Binoculars 10.1427
# 11                  CameraHousing  8.6338
# 2                             NPS  5.8125
# 0   adStock_Traditional Marketing  5.4100
# 10                   CameraEyeCup  5.3349
# 5                 CameraAccessory  4.4498
# 1         adStock_Other Marketing  4.0917
# 15                   CameraTripod  3.7612
# 9               CameraBatteryGrip  3.2687
# 21              ReflectorUmbrella  2.6775
# 3                  total_pay_days  1.7469
# Removing Lens due to high p-value (0.8868)
#
# ========== Iteration 3: Training Model ==========
#
# Model Summary (Iteration 3):
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    gmv   R-squared:                       0.995
# Model:                            OLS   Adj. R-squared:                  0.990
# Method:                 Least Squares   F-statistic:                     193.2
# Date:                Mon, 17 Mar 2025   Prob (F-statistic):           6.44e-18
# Time:                        02:03:40   Log-Likelihood:                -518.76
# No. Observations:                  41   AIC:                             1082.
# Df Residuals:                      19   BIC:                             1119.
# Df Model:                          21
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# const                          2.513e+06    1.8e+04    139.605      0.000    2.48e+06    2.55e+06
# adStock_Traditional Marketing -5.637e+04   3.79e+04     -1.486      0.154   -1.36e+05     2.3e+04
# adStock_Other Marketing         8.61e+04   3.49e+04      2.468      0.023    1.31e+04    1.59e+05
# NPS                           -4.608e+04   4.19e+04     -1.100      0.285   -1.34e+05    4.16e+04
# total_pay_days                -4.143e+04   2.11e+04     -1.963      0.065   -8.56e+04    2752.621
# Binoculars                     2.011e+05   5.48e+04      3.669      0.002    8.64e+04    3.16e+05
# CameraAccessory               -3.976e+04   3.66e+04     -1.086      0.291   -1.16e+05    3.69e+04
# CameraBag                      5.985e+04   1.05e+05      0.568      0.577   -1.61e+05     2.8e+05
# CameraBattery                  2.092e+05   7.31e+04      2.861      0.010    5.61e+04    3.62e+05
# CameraBatteryCharger           3.342e+04   8.29e+04      0.403      0.691    -1.4e+05    2.07e+05
# CameraBatteryGrip              7.324e+04   3.13e+04      2.338      0.031    7662.710    1.39e+05
# CameraEyeCup                   5.724e+04   3.69e+04      1.550      0.138   -2.01e+04    1.35e+05
# CameraHousing                   3.66e+04   4.31e+04      0.849      0.407   -5.37e+04    1.27e+05
# CameraMicrophone              -7.712e+04   5.29e+04     -1.459      0.161   -1.88e+05    3.35e+04
# CameraMount                    7.306e+04   5.23e+04      1.397      0.178   -3.64e+04    1.83e+05
# CameraRemoteControl            1.079e+05   7.43e+04      1.452      0.163   -4.76e+04    2.63e+05
# CameraTripod                   1.969e+05   3.32e+04      5.932      0.000    1.27e+05    2.66e+05
# ExtensionTube                  2.603e+04    4.4e+04      0.592      0.561   -6.61e+04    1.18e+05
# Filter                          2.39e+05   8.05e+04      2.970      0.008    7.06e+04    4.07e+05
# Flash                          1.839e+05   4.81e+04      3.820      0.001    8.31e+04    2.85e+05
# Strap                           5.11e+04   6.36e+04      0.803      0.432    -8.2e+04    1.84e+05
# ReflectorUmbrella             -6.658e+04   4.92e+04     -1.353      0.192    -1.7e+05    3.64e+04
# ==============================================================================
# Omnibus:                        2.942   Durbin-Watson:                   2.189
# Prob(Omnibus):                  0.230   Jarque-Bera (JB):                2.139
# Skew:                           0.554   Prob(JB):                        0.343
# Kurtosis:                       3.157   Cond. No.                         23.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# VIF Values (Iteration 3):
#                           Feature     VIF
# 6                       CameraBag 36.8757
# 8            CameraBatteryCharger 22.8289
# 17                         Filter 21.4194
# 14            CameraRemoteControl 18.0293
# 7                   CameraBattery 17.7116
# 19                          Strap 13.4305
# 4                      Binoculars  9.9479
# 12               CameraMicrophone  9.2794
# 13                    CameraMount  9.0798
# 18                          Flash  7.6795
# 16                  ExtensionTube  6.3485
# 11                  CameraHousing  6.1750
# 2                             NPS  5.8119
# 0   adStock_Traditional Marketing  4.7483
# 10                   CameraEyeCup  4.5207
# 5                 CameraAccessory  4.4198
# 1         adStock_Other Marketing  4.0221
# 15                   CameraTripod  3.6551
# 9               CameraBatteryGrip  3.2592
# 20              ReflectorUmbrella  1.8225
# 3                  total_pay_days  1.4785
# Removing CameraBatteryCharger due to high p-value (0.6914)
#
# ========== Iteration 4: Training Model ==========
#
# Model Summary (Iteration 4):
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    gmv   R-squared:                       0.995
# Model:                            OLS   Adj. R-squared:                  0.991
# Method:                 Least Squares   F-statistic:                     211.8
# Date:                Mon, 17 Mar 2025   Prob (F-statistic):           4.68e-19
# Time:                        02:03:40   Log-Likelihood:                -518.93
# No. Observations:                  41   AIC:                             1080.
# Df Residuals:                      20   BIC:                             1116.
# Df Model:                          20
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# const                          2.513e+06   1.76e+04    142.623      0.000    2.48e+06    2.55e+06
# adStock_Traditional Marketing   -5.2e+04   3.56e+04     -1.461      0.160   -1.26e+05    2.22e+04
# adStock_Other Marketing        9.203e+04    3.1e+04      2.972      0.008    2.74e+04    1.57e+05
# NPS                            -4.25e+04   4.01e+04     -1.061      0.302   -1.26e+05    4.11e+04
# total_pay_days                -4.145e+04   2.07e+04     -2.006      0.059   -8.45e+04    1658.391
# Binoculars                     1.976e+05    5.3e+04      3.730      0.001    8.71e+04    3.08e+05
# CameraAccessory               -4.238e+04   3.53e+04     -1.201      0.244   -1.16e+05    3.12e+04
# CameraBag                       6.75e+04   1.01e+05      0.665      0.514   -1.44e+05    2.79e+05
# CameraBattery                  2.243e+05   6.14e+04      3.655      0.002    9.63e+04    3.52e+05
# CameraBatteryGrip              7.646e+04   2.97e+04      2.578      0.018    1.46e+04    1.38e+05
# CameraEyeCup                   5.509e+04   3.58e+04      1.540      0.139   -1.95e+04     1.3e+05
# CameraHousing                  4.198e+04   4.01e+04      1.046      0.308   -4.17e+04    1.26e+05
# CameraMicrophone              -6.506e+04   4.27e+04     -1.525      0.143   -1.54e+05    2.39e+04
# CameraMount                    6.922e+04   5.03e+04      1.375      0.184   -3.58e+04    1.74e+05
# CameraRemoteControl            1.088e+05   7.27e+04      1.498      0.150   -4.27e+04     2.6e+05
# CameraTripod                   1.964e+05   3.25e+04      6.050      0.000    1.29e+05    2.64e+05
# ExtensionTube                  2.413e+04   4.28e+04      0.564      0.579   -6.52e+04    1.13e+05
# Filter                         2.369e+05   7.86e+04      3.014      0.007    7.29e+04    4.01e+05
# Flash                          1.856e+05   4.69e+04      3.957      0.001    8.78e+04    2.84e+05
# Strap                          6.174e+04   5.66e+04      1.090      0.289   -5.64e+04     1.8e+05
# ReflectorUmbrella             -6.667e+04   4.82e+04     -1.384      0.182   -1.67e+05    3.38e+04
# ==============================================================================
# Omnibus:                        2.520   Durbin-Watson:                   2.174
# Prob(Omnibus):                  0.284   Jarque-Bera (JB):                1.825
# Skew:                           0.514   Prob(JB):                        0.402
# Kurtosis:                       3.099   Cond. No.                         21.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# VIF Values (Iteration 4):
#                           Feature     VIF
# 6                       CameraBag 35.6825
# 16                         Filter 21.3280
# 13            CameraRemoteControl 18.0103
# 7                   CameraBattery 13.0076
# 18                          Strap 11.1166
# 4                      Binoculars  9.7016
# 12                    CameraMount  8.7789
# 17                          Flash  7.6142
# 11               CameraMicrophone  6.3065
# 15                  ExtensionTube  6.2744
# 10                  CameraHousing  5.5830
# 2                             NPS  5.5500
# 9                    CameraEyeCup  4.4261
# 0   adStock_Traditional Marketing  4.3573
# 5                 CameraAccessory  4.2794
# 14                   CameraTripod  3.6516
# 1         adStock_Other Marketing  3.3038
# 8               CameraBatteryGrip  3.0473
# 19              ReflectorUmbrella  1.8224
# 3                  total_pay_days  1.4785
# Removing ExtensionTube due to high p-value (0.5794)
#
# ========== Iteration 5: Training Model ==========
#
# Model Summary (Iteration 5):
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    gmv   R-squared:                       0.995
# Model:                            OLS   Adj. R-squared:                  0.991
# Method:                 Least Squares   F-statistic:                     230.4
# Date:                Mon, 17 Mar 2025   Prob (F-statistic):           3.51e-20
# Time:                        02:03:40   Log-Likelihood:                -519.25
# No. Observations:                  41   AIC:                             1079.
# Df Residuals:                      21   BIC:                             1113.
# Df Model:                          19
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# const                          2.512e+06   1.72e+04    145.861      0.000    2.48e+06    2.55e+06
# adStock_Traditional Marketing -5.415e+04   3.48e+04     -1.556      0.135   -1.27e+05    1.82e+04
# adStock_Other Marketing        9.219e+04   3.05e+04      3.027      0.006    2.88e+04    1.56e+05
# NPS                           -4.165e+04   3.94e+04     -1.057      0.302   -1.24e+05    4.03e+04
# total_pay_days                 -4.29e+04   2.02e+04     -2.128      0.045   -8.48e+04    -968.100
# Binoculars                     2.015e+05   5.17e+04      3.898      0.001     9.4e+04    3.09e+05
# CameraAccessory               -3.887e+04   3.42e+04     -1.138      0.268    -1.1e+05    3.22e+04
# CameraBag                      4.805e+04   9.39e+04      0.512      0.614   -1.47e+05    2.43e+05
# CameraBattery                  2.392e+05   5.45e+04      4.389      0.000    1.26e+05    3.53e+05
# CameraBatteryGrip               7.69e+04   2.92e+04      2.637      0.015    1.63e+04    1.38e+05
# CameraEyeCup                   5.943e+04   3.44e+04      1.730      0.098    -1.2e+04    1.31e+05
# CameraHousing                  3.644e+04   3.83e+04      0.952      0.352   -4.32e+04    1.16e+05
# CameraMicrophone              -7.098e+04   4.07e+04     -1.745      0.096   -1.56e+05    1.36e+04
# CameraMount                     8.23e+04   4.39e+04      1.874      0.075   -9039.888    1.74e+05
# CameraRemoteControl            8.573e+04    5.9e+04      1.453      0.161    -3.7e+04    2.08e+05
# CameraTripod                   1.916e+05   3.08e+04      6.223      0.000    1.28e+05    2.56e+05
# Filter                         2.597e+05   6.63e+04      3.915      0.001    1.22e+05    3.98e+05
# Flash                          1.791e+05   4.47e+04      4.006      0.001    8.61e+04    2.72e+05
# Strap                          6.981e+04   5.39e+04      1.295      0.209   -4.23e+04    1.82e+05
# ReflectorUmbrella             -5.522e+04    4.3e+04     -1.285      0.213   -1.45e+05    3.41e+04
# ==============================================================================
# Omnibus:                        3.171   Durbin-Watson:                   2.224
# Prob(Omnibus):                  0.205   Jarque-Bera (JB):                2.407
# Skew:                           0.591   Prob(JB):                        0.300
# Kurtosis:                       3.113   Cond. No.                         18.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# VIF Values (Iteration 5):
#                           Feature     VIF
# 6                       CameraBag 31.5698
# 15                         Filter 15.7602
# 13            CameraRemoteControl 12.3992
# 7                   CameraBattery 10.6408
# 17                          Strap 10.4068
# 4                      Binoculars  9.5553
# 16                          Flash  7.1567
# 12                    CameraMount  6.8979
# 11               CameraMicrophone  5.9144
# 2                             NPS  5.5392
# 10                  CameraHousing  5.2460
# 0   adStock_Traditional Marketing  4.3151
# 9                    CameraEyeCup  4.2077
# 5                 CameraAccessory  4.1586
# 14                   CameraTripod  3.3956
# 1         adStock_Other Marketing  3.3027
# 8               CameraBatteryGrip  3.0448
# 18              ReflectorUmbrella  1.5170
# 3                  total_pay_days  1.4564
# Removing CameraBag due to high p-value (0.6141)
#
# ========== Iteration 6: Training Model ==========
#
# Model Summary (Iteration 6):
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    gmv   R-squared:                       0.995
# Model:                            OLS   Adj. R-squared:                  0.991
# Method:                 Least Squares   F-statistic:                     251.6
# Date:                Mon, 17 Mar 2025   Prob (F-statistic):           2.46e-21
# Time:                        02:03:40   Log-Likelihood:                -519.51
# No. Observations:                  41   AIC:                             1077.
# Df Residuals:                      22   BIC:                             1110.
# Df Model:                          18
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# const                          2.512e+06   1.69e+04    148.392      0.000    2.48e+06    2.55e+06
# adStock_Traditional Marketing  -5.53e+04   3.41e+04     -1.619      0.120   -1.26e+05    1.55e+04
# adStock_Other Marketing        9.453e+04   2.96e+04      3.194      0.004    3.31e+04    1.56e+05
# NPS                           -3.742e+04   3.79e+04     -0.988      0.334   -1.16e+05    4.11e+04
# total_pay_days                -4.462e+04   1.95e+04     -2.282      0.033   -8.52e+04   -4071.686
# Binoculars                     2.152e+05   4.34e+04      4.963      0.000    1.25e+05    3.05e+05
# CameraAccessory               -3.662e+04   3.33e+04     -1.100      0.283   -1.06e+05    3.24e+04
# CameraBattery                  2.502e+05   4.93e+04      5.078      0.000    1.48e+05    3.52e+05
# CameraBatteryGrip               7.18e+04   2.69e+04      2.665      0.014    1.59e+04    1.28e+05
# CameraEyeCup                   6.099e+04   3.36e+04      1.813      0.083   -8771.355    1.31e+05
# CameraHousing                  4.137e+04   3.64e+04      1.136      0.268   -3.41e+04    1.17e+05
# CameraMicrophone              -8.029e+04   3.58e+04     -2.246      0.035   -1.54e+05   -6142.705
# CameraMount                    8.129e+04   4.31e+04      1.885      0.073   -8167.628    1.71e+05
# CameraRemoteControl            9.158e+04   5.69e+04      1.609      0.122   -2.64e+04     2.1e+05
# CameraTripod                   1.883e+05   2.96e+04      6.361      0.000    1.27e+05     2.5e+05
# Filter                         2.803e+05   5.17e+04      5.423      0.000    1.73e+05    3.88e+05
# Flash                          1.763e+05   4.36e+04      4.042      0.001    8.59e+04    2.67e+05
# Strap                           8.21e+04   4.74e+04      1.731      0.098   -1.63e+04     1.8e+05
# ReflectorUmbrella             -5.646e+04   4.22e+04     -1.339      0.194   -1.44e+05     3.1e+04
# ==============================================================================
# Omnibus:                        4.054   Durbin-Watson:                   2.230
# Prob(Omnibus):                  0.132   Jarque-Bera (JB):                3.160
# Skew:                           0.673   Prob(JB):                        0.206
# Kurtosis:                       3.189   Cond. No.                         12.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# VIF Values (Iteration 6):
#                           Feature     VIF
# 12            CameraRemoteControl 11.9362
# 14                         Filter  9.9034
# 6                   CameraBattery  8.9941
# 16                          Strap  8.3435
# 15                          Flash  7.0519
# 4                      Binoculars  6.9490
# 11                    CameraMount  6.8835
# 2                             NPS  5.2961
# 9                   CameraHousing  4.9125
# 10               CameraMicrophone  4.7312
# 0   adStock_Traditional Marketing  4.2965
# 8                    CameraEyeCup  4.1753
# 5                 CameraAccessory  4.0877
# 13                   CameraTripod  3.2486
# 1         adStock_Other Marketing  3.2285
# 7               CameraBatteryGrip  2.6879
# 17              ReflectorUmbrella  1.5125
# 3                  total_pay_days  1.4162
# Removing NPS due to high p-value (0.3337)
#
# ========== Iteration 7: Training Model ==========
#
# Model Summary (Iteration 7):
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    gmv   R-squared:                       0.995
# Model:                            OLS   Adj. R-squared:                  0.991
# Method:                 Least Squares   F-statistic:                     266.6
# Date:                Mon, 17 Mar 2025   Prob (F-statistic):           2.36e-22
# Time:                        02:03:40   Log-Likelihood:                -520.40
# No. Observations:                  41   AIC:                             1077.
# Df Residuals:                      23   BIC:                             1108.
# Df Model:                          17
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# const                          2.513e+06   1.69e+04    148.761      0.000    2.48e+06    2.55e+06
# adStock_Traditional Marketing -3.155e+04   2.43e+04     -1.301      0.206   -8.17e+04    1.86e+04
# adStock_Other Marketing        1.058e+05   2.73e+04      3.874      0.001    4.93e+04    1.62e+05
# total_pay_days                -4.773e+04   1.93e+04     -2.475      0.021   -8.76e+04   -7837.970
# Binoculars                     2.104e+05   4.31e+04      4.886      0.000    1.21e+05    2.99e+05
# CameraAccessory               -3.366e+04   3.31e+04     -1.015      0.320   -1.02e+05    3.49e+04
# CameraBattery                  2.386e+05   4.78e+04      4.989      0.000     1.4e+05    3.38e+05
# CameraBatteryGrip              7.496e+04   2.67e+04      2.804      0.010    1.97e+04     1.3e+05
# CameraEyeCup                   5.886e+04   3.36e+04      1.754      0.093   -1.05e+04    1.28e+05
# CameraHousing                  3.977e+04   3.64e+04      1.094      0.285   -3.54e+04    1.15e+05
# CameraMicrophone              -9.571e+04   3.22e+04     -2.976      0.007   -1.62e+05   -2.92e+04
# CameraMount                    8.959e+04   4.23e+04      2.118      0.045    2101.649    1.77e+05
# CameraRemoteControl             1.12e+05    5.3e+04      2.112      0.046    2291.100    2.22e+05
# CameraTripod                   1.927e+05   2.92e+04      6.591      0.000    1.32e+05    2.53e+05
# Filter                         2.671e+05   4.99e+04      5.353      0.000    1.64e+05     3.7e+05
# Flash                           1.85e+05   4.27e+04      4.332      0.000    9.67e+04    2.73e+05
# Strap                          9.416e+04   4.58e+04      2.055      0.051    -626.252    1.89e+05
# ReflectorUmbrella             -6.615e+04    4.1e+04     -1.614      0.120   -1.51e+05    1.86e+04
# ==============================================================================
# Omnibus:                        3.440   Durbin-Watson:                   2.132
# Prob(Omnibus):                  0.179   Jarque-Bera (JB):                2.553
# Skew:                           0.603   Prob(JB):                        0.279
# Kurtosis:                       3.200   Cond. No.                         10.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# VIF Values (Iteration 7):
#                           Feature     VIF
# 11            CameraRemoteControl 10.3926
# 13                         Filter  9.2393
# 5                   CameraBattery  8.4877
# 15                          Strap  7.7909
# 3                      Binoculars  6.8651
# 14                          Flash  6.7679
# 10                    CameraMount  6.6285
# 8                   CameraHousing  4.9033
# 7                    CameraEyeCup  4.1558
# 4                 CameraAccessory  4.0512
# 9                CameraMicrophone  3.8361
# 12                   CameraTripod  3.1736
# 1         adStock_Other Marketing  2.7573
# 6               CameraBatteryGrip  2.6509
# 0   adStock_Traditional Marketing  2.1763
# 16              ReflectorUmbrella  1.4353
# 2                  total_pay_days  1.3787
# Removing CameraAccessory due to high p-value (0.3205)
#
# ========== Iteration 8: Training Model ==========
#
# Model Summary (Iteration 8):
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    gmv   R-squared:                       0.995
# Model:                            OLS   Adj. R-squared:                  0.991
# Method:                 Least Squares   F-statistic:                     282.9
# Date:                Mon, 17 Mar 2025   Prob (F-statistic):           2.26e-23
# Time:                        02:03:40   Log-Likelihood:                -521.30
# No. Observations:                  41   AIC:                             1077.
# Df Residuals:                      24   BIC:                             1106.
# Df Model:                          16
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# const                          2.512e+06   1.69e+04    149.057      0.000    2.48e+06    2.55e+06
# adStock_Traditional Marketing -3.115e+04   2.43e+04     -1.284      0.211   -8.12e+04    1.89e+04
# adStock_Other Marketing        9.501e+04   2.52e+04      3.773      0.001     4.3e+04    1.47e+05
# total_pay_days                -4.446e+04    1.9e+04     -2.337      0.028   -8.37e+04   -5194.181
# Binoculars                     2.207e+05   4.19e+04      5.270      0.000    1.34e+05    3.07e+05
# CameraBattery                  2.335e+05   4.76e+04      4.906      0.000    1.35e+05    3.32e+05
# CameraBatteryGrip              6.826e+04   2.59e+04      2.633      0.015    1.48e+04    1.22e+05
# CameraEyeCup                   5.196e+04   3.29e+04      1.580      0.127   -1.59e+04     1.2e+05
# CameraHousing                  3.161e+04   3.55e+04      0.891      0.382   -4.16e+04    1.05e+05
# CameraMicrophone              -9.332e+04   3.21e+04     -2.908      0.008    -1.6e+05   -2.71e+04
# CameraMount                     7.81e+04   4.08e+04      1.915      0.067   -6056.686    1.62e+05
# CameraRemoteControl            8.968e+04   4.83e+04      1.857      0.076   -9990.139    1.89e+05
# CameraTripod                   1.851e+05   2.83e+04      6.545      0.000    1.27e+05    2.43e+05
# Filter                         2.695e+05   4.99e+04      5.404      0.000    1.67e+05    3.72e+05
# Flash                          1.904e+05   4.24e+04      4.492      0.000    1.03e+05    2.78e+05
# Strap                          9.787e+04   4.57e+04      2.141      0.043    3540.478    1.92e+05
# ReflectorUmbrella             -5.215e+04   3.86e+04     -1.350      0.190   -1.32e+05    2.76e+04
# ==============================================================================
# Omnibus:                        2.748   Durbin-Watson:                   1.992
# Prob(Omnibus):                  0.253   Jarque-Bera (JB):                1.814
# Skew:                           0.493   Prob(JB):                        0.404
# Kurtosis:                       3.297   Cond. No.                         9.78
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# VIF Values (Iteration 8):
#                           Feature    VIF
# 12                         Filter 9.2181
# 10            CameraRemoteControl 8.6355
# 4                   CameraBattery 8.3920
# 14                          Strap 7.7419
# 13                          Flash 6.6597
# 3                      Binoculars 6.4943
# 9                     CameraMount 6.1610
# 7                   CameraHousing 4.6580
# 6                    CameraEyeCup 3.9931
# 8                CameraMicrophone 3.8163
# 11                   CameraTripod 2.9627
# 5               CameraBatteryGrip 2.4904
# 1         adStock_Other Marketing 2.3470
# 0   adStock_Traditional Marketing 2.1754
# 2                  total_pay_days 1.3388
# 15              ReflectorUmbrella 1.2809
# Removing CameraHousing due to high p-value (0.3819)
#
# ========== Iteration 9: Training Model ==========
#
# Model Summary (Iteration 9):
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    gmv   R-squared:                       0.995
# Model:                            OLS   Adj. R-squared:                  0.991
# Method:                 Least Squares   F-statistic:                     304.2
# Date:                Mon, 17 Mar 2025   Prob (F-statistic):           1.86e-24
# Time:                        02:03:40   Log-Likelihood:                -521.96
# No. Observations:                  41   AIC:                             1076.
# Df Residuals:                      25   BIC:                             1103.
# Df Model:                          15
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# const                          2.513e+06   1.68e+04    149.844      0.000    2.48e+06    2.55e+06
# adStock_Traditional Marketing  -3.08e+04   2.42e+04     -1.275      0.214   -8.06e+04     1.9e+04
# adStock_Other Marketing        9.089e+04   2.46e+04      3.687      0.001    4.01e+04    1.42e+05
# total_pay_days                -4.661e+04   1.88e+04     -2.480      0.020   -8.53e+04   -7906.339
# Binoculars                     2.124e+05   4.07e+04      5.223      0.000    1.29e+05    2.96e+05
# CameraBattery                  2.355e+05   4.73e+04      4.975      0.000    1.38e+05    3.33e+05
# CameraBatteryGrip              6.242e+04    2.5e+04      2.499      0.019     1.1e+04    1.14e+05
# CameraEyeCup                   6.361e+04      3e+04      2.118      0.044    1747.193    1.25e+05
# CameraMicrophone               -1.02e+05   3.05e+04     -3.347      0.003   -1.65e+05   -3.92e+04
# CameraMount                    6.657e+04   3.85e+04      1.729      0.096   -1.27e+04    1.46e+05
# CameraRemoteControl             9.18e+04    4.8e+04      1.911      0.068   -7122.611    1.91e+05
# CameraTripod                   1.808e+05   2.78e+04      6.515      0.000    1.24e+05    2.38e+05
# Filter                         2.757e+05   4.92e+04      5.606      0.000    1.74e+05    3.77e+05
# Flash                          1.955e+05   4.18e+04      4.672      0.000    1.09e+05    2.82e+05
# Strap                          1.173e+05      4e+04      2.933      0.007    3.49e+04       2e+05
# ReflectorUmbrella             -5.857e+04   3.78e+04     -1.550      0.134   -1.36e+05    1.92e+04
# ==============================================================================
# Omnibus:                        3.707   Durbin-Watson:                   2.067
# Prob(Omnibus):                  0.157   Jarque-Bera (JB):                2.701
# Skew:                           0.612   Prob(JB):                        0.259
# Kurtosis:                       3.292   Cond. No.                         9.64
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# VIF Values (Iteration 9):
#                           Feature    VIF
# 11                         Filter 9.0384
# 9             CameraRemoteControl 8.6155
# 4                   CameraBattery 8.3724
# 12                          Flash 6.5417
# 3                      Binoculars 6.1782
# 13                          Strap 5.9739
# 8                     CameraMount 5.5362
# 7                CameraMicrophone 3.4679
# 6                    CameraEyeCup 3.3653
# 10                   CameraTripod 2.8785
# 5               CameraBatteryGrip 2.3306
# 1         adStock_Other Marketing 2.2663
# 0   adStock_Traditional Marketing 2.1750
# 2                  total_pay_days 1.3165
# 14              ReflectorUmbrella 1.2384
# Removing adStock_Traditional Marketing due to high p-value (0.2141)
#
# ========== Iteration 10: Training Model ==========
#
# Model Summary (Iteration 10):
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    gmv   R-squared:                       0.994
# Model:                            OLS   Adj. R-squared:                  0.991
# Method:                 Least Squares   F-statistic:                     318.1
# Date:                Mon, 17 Mar 2025   Prob (F-statistic):           2.23e-25
# Time:                        02:03:40   Log-Likelihood:                -523.26
# No. Observations:                  41   AIC:                             1077.
# Df Residuals:                      26   BIC:                             1102.
# Df Model:                          14
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                    2.514e+06   1.69e+04    148.361      0.000    2.48e+06    2.55e+06
# adStock_Other Marketing  9.789e+04   2.43e+04      4.026      0.000    4.79e+04    1.48e+05
# total_pay_days          -3.882e+04    1.8e+04     -2.158      0.040   -7.58e+04   -1850.325
# Binoculars               2.117e+05   4.12e+04      5.143      0.000    1.27e+05    2.96e+05
# CameraBattery            2.319e+05   4.78e+04      4.850      0.000    1.34e+05     3.3e+05
# CameraBatteryGrip        5.941e+04   2.52e+04      2.361      0.026    7689.498    1.11e+05
# CameraEyeCup             6.682e+04   3.03e+04      2.206      0.036    4556.879    1.29e+05
# CameraMicrophone        -1.026e+05   3.08e+04     -3.329      0.003   -1.66e+05   -3.92e+04
# CameraMount              6.919e+04   3.89e+04      1.778      0.087   -1.08e+04    1.49e+05
# CameraRemoteControl      9.494e+04   4.85e+04      1.956      0.061   -4845.836    1.95e+05
# CameraTripod             1.708e+05   2.69e+04      6.340      0.000    1.15e+05    2.26e+05
# Filter                   2.663e+05   4.92e+04      5.412      0.000    1.65e+05    3.67e+05
# Flash                     2.05e+05   4.17e+04      4.922      0.000    1.19e+05    2.91e+05
# Strap                    1.093e+05      4e+04      2.735      0.011    2.72e+04    1.92e+05
# ReflectorUmbrella       -7.048e+04   3.71e+04     -1.902      0.068   -1.47e+05    5682.709
# ==============================================================================
# Omnibus:                        3.994   Durbin-Watson:                   2.110
# Prob(Omnibus):                  0.136   Jarque-Bera (JB):                2.778
# Skew:                           0.580   Prob(JB):                        0.249
# Kurtosis:                       3.529   Cond. No.                         9.33
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# VIF Values (Iteration 10):
#                     Feature    VIF
# 10                   Filter 8.8347
# 8       CameraRemoteControl 8.5941
# 3             CameraBattery 8.3442
# 11                    Flash 6.3331
# 2                Binoculars 6.1770
# 12                    Strap 5.8300
# 7               CameraMount 5.5214
# 6          CameraMicrophone 3.4669
# 5              CameraEyeCup 3.3429
# 9              CameraTripod 2.6497
# 4         CameraBatteryGrip 2.3094
# 0   adStock_Other Marketing 2.1556
# 1            total_pay_days 1.1787
# 13        ReflectorUmbrella 1.1662
# Removing CameraMount due to high p-value (0.0871)
#
# ========== Iteration 11: Training Model ==========
#
# Model Summary (Iteration 11):
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    gmv   R-squared:                       0.993
# Model:                            OLS   Adj. R-squared:                  0.990
# Method:                 Least Squares   F-statistic:                     317.0
# Date:                Mon, 17 Mar 2025   Prob (F-statistic):           5.38e-26
# Time:                        02:03:40   Log-Likelihood:                -525.61
# No. Observations:                  41   AIC:                             1079.
# Df Residuals:                      27   BIC:                             1103.
# Df Model:                          13
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                    2.513e+06   1.76e+04    142.763      0.000    2.48e+06    2.55e+06
# adStock_Other Marketing  1.015e+05   2.52e+04      4.030      0.000    4.98e+04    1.53e+05
# total_pay_days          -3.863e+04   1.87e+04     -2.067      0.048    -7.7e+04    -278.052
# Binoculars               2.055e+05   4.26e+04      4.822      0.000    1.18e+05    2.93e+05
# CameraBattery            2.619e+05   4.65e+04      5.628      0.000    1.66e+05    3.57e+05
# CameraBatteryGrip         6.97e+04   2.54e+04      2.739      0.011    1.75e+04    1.22e+05
# CameraEyeCup             4.774e+04   2.94e+04      1.622      0.117   -1.27e+04    1.08e+05
# CameraMicrophone        -6.854e+04   2.51e+04     -2.731      0.011    -1.2e+05   -1.71e+04
# CameraRemoteControl      8.357e+04      5e+04      1.671      0.106    -1.9e+04    1.86e+05
# CameraTripod             1.758e+05   2.79e+04      6.310      0.000    1.19e+05    2.33e+05
# Filter                   2.628e+05   5.11e+04      5.144      0.000    1.58e+05    3.68e+05
# Flash                    2.334e+05      4e+04      5.838      0.000    1.51e+05    3.15e+05
# Strap                    1.086e+05   4.15e+04      2.614      0.014    2.34e+04    1.94e+05
# ReflectorUmbrella       -6.205e+04   3.82e+04     -1.625      0.116    -1.4e+05    1.63e+04
# ==============================================================================
# Omnibus:                        5.963   Durbin-Watson:                   1.921
# Prob(Omnibus):                  0.051   Jarque-Bera (JB):                4.665
# Skew:                           0.764   Prob(JB):                       0.0970
# Kurtosis:                       3.628   Cond. No.                         8.78
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# VIF Values (Iteration 11):
#                     Feature    VIF
# 9                    Filter 8.8210
# 7       CameraRemoteControl 8.4464
# 3             CameraBattery 7.3130
# 2                Binoculars 6.1329
# 11                    Strap 5.8293
# 10                    Flash 5.4015
# 5              CameraEyeCup 2.9248
# 8              CameraTripod 2.6218
# 4         CameraBatteryGrip 2.1865
# 0   adStock_Other Marketing 2.1402
# 6          CameraMicrophone 2.1261
# 1            total_pay_days 1.1786
# 12        ReflectorUmbrella 1.1480
# Removing CameraEyeCup due to high p-value (0.1165)
#
# ========== Iteration 12: Training Model ==========
#
# Model Summary (Iteration 12):
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    gmv   R-squared:                       0.993
# Model:                            OLS   Adj. R-squared:                  0.990
# Method:                 Least Squares   F-statistic:                     324.3
# Date:                Mon, 17 Mar 2025   Prob (F-statistic):           1.01e-26
# Time:                        02:03:40   Log-Likelihood:                -527.51
# No. Observations:                  41   AIC:                             1081.
# Df Residuals:                      28   BIC:                             1103.
# Df Model:                          12
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                    2.512e+06   1.81e+04    138.804      0.000    2.47e+06    2.55e+06
# adStock_Other Marketing  8.232e+04   2.29e+04      3.599      0.001    3.55e+04    1.29e+05
# total_pay_days          -4.218e+04   1.91e+04     -2.210      0.035   -8.13e+04   -3076.024
# Binoculars               1.997e+05   4.37e+04      4.571      0.000     1.1e+05    2.89e+05
# CameraBattery            2.576e+05   4.78e+04      5.392      0.000     1.6e+05    3.56e+05
# CameraBatteryGrip        7.305e+04   2.61e+04      2.800      0.009    1.96e+04    1.26e+05
# CameraMicrophone        -7.142e+04   2.57e+04     -2.774      0.010   -1.24e+05   -1.87e+04
# CameraRemoteControl      6.255e+04   4.97e+04      1.259      0.218   -3.92e+04    1.64e+05
# CameraTripod             1.719e+05   2.85e+04      6.020      0.000    1.13e+05     2.3e+05
# Filter                   2.791e+05   5.15e+04      5.415      0.000    1.74e+05    3.85e+05
# Flash                    2.565e+05   3.84e+04      6.674      0.000    1.78e+05    3.35e+05
# Strap                    1.316e+05   4.02e+04      3.275      0.003    4.93e+04    2.14e+05
# ReflectorUmbrella       -5.252e+04   3.88e+04     -1.353      0.187   -1.32e+05     2.7e+04
# ==============================================================================
# Omnibus:                        4.649   Durbin-Watson:                   1.988
# Prob(Omnibus):                  0.098   Jarque-Bera (JB):                3.656
# Skew:                           0.719   Prob(JB):                        0.161
# Kurtosis:                       3.267   Cond. No.                         8.30
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# VIF Values (Iteration 12):
#                     Feature    VIF
# 8                    Filter 8.4821
# 6       CameraRemoteControl 7.8810
# 3             CameraBattery 7.2897
# 2                Binoculars 6.0881
# 10                    Strap 5.1529
# 9                     Flash 4.7134
# 7              CameraTripod 2.6022
# 4         CameraBatteryGrip 2.1718
# 5          CameraMicrophone 2.1156
# 0   adStock_Other Marketing 1.6697
# 1            total_pay_days 1.1627
# 11        ReflectorUmbrella 1.1220
# Removing CameraRemoteControl due to high p-value (0.2185)
#
# ========== Final Model Summary ==========
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    gmv   R-squared:                       0.992
# Model:                            OLS   Adj. R-squared:                  0.990
# Method:                 Least Squares   F-statistic:                     346.6
# Date:                Mon, 17 Mar 2025   Prob (F-statistic):           1.14e-27
# Time:                        02:03:40   Log-Likelihood:                -528.64
# No. Observations:                  41   AIC:                             1081.
# Df Residuals:                      29   BIC:                             1102.
# Df Model:                          11
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                    2.512e+06   1.83e+04    137.421      0.000    2.47e+06    2.55e+06
# adStock_Other Marketing  7.278e+04   2.18e+04      3.339      0.002    2.82e+04    1.17e+05
# total_pay_days          -4.551e+04   1.91e+04     -2.383      0.024   -8.46e+04   -6444.078
# Binoculars               2.006e+05   4.41e+04      4.546      0.000     1.1e+05    2.91e+05
# CameraBattery            2.869e+05   4.21e+04      6.808      0.000    2.01e+05    3.73e+05
# CameraBatteryGrip        7.906e+04   2.59e+04      3.052      0.005    2.61e+04    1.32e+05
# CameraMicrophone        -7.387e+04   2.59e+04     -2.849      0.008   -1.27e+05   -2.08e+04
# CameraTripod             1.732e+05   2.88e+04      6.012      0.000    1.14e+05    2.32e+05
# Filter                   3.118e+05   4.49e+04      6.940      0.000     2.2e+05    4.04e+05
# Flash                    2.463e+05    3.8e+04      6.491      0.000    1.69e+05    3.24e+05
# Strap                    1.274e+05   4.04e+04      3.151      0.004    4.47e+04     2.1e+05
# ReflectorUmbrella       -4.931e+04   3.91e+04     -1.261      0.218   -1.29e+05    3.07e+04
# ==============================================================================
# Omnibus:                        1.779   Durbin-Watson:                   2.054
# Prob(Omnibus):                  0.411   Jarque-Bera (JB):                1.658
# Skew:                           0.461   Prob(JB):                        0.436
# Kurtosis:                       2.651   Cond. No.                         7.18
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ========== Final VIF Values ==========
#                     Feature    VIF
# 7                    Filter 6.3177
# 2                Binoculars 6.0867
# 3             CameraBattery 5.5601
# 9                     Strap 5.1181
# 8                     Flash 4.5048
# 6              CameraTripod 2.5985
# 5          CameraMicrophone 2.1037
# 4         CameraBatteryGrip 2.0987
# 0   adStock_Other Marketing 1.4863
# 1            total_pay_days 1.1406
# 10        ReflectorUmbrella 1.1174
# 2025/03/17 02:03:43 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.

# %%
# get the final model summary
print(final_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    gmv   R-squared:                       0.992
# Model:                            OLS   Adj. R-squared:                  0.990
# Method:                 Least Squares   F-statistic:                     346.6
# Date:                Mon, 17 Mar 2025   Prob (F-statistic):           1.14e-27
# Time:                        02:04:02   Log-Likelihood:                -528.64
# No. Observations:                  41   AIC:                             1081.
# Df Residuals:                      29   BIC:                             1102.
# Df Model:                          11
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                    2.512e+06   1.83e+04    137.421      0.000    2.47e+06    2.55e+06
# adStock_Other Marketing  7.278e+04   2.18e+04      3.339      0.002    2.82e+04    1.17e+05
# total_pay_days          -4.551e+04   1.91e+04     -2.383      0.024   -8.46e+04   -6444.078
# Binoculars               2.006e+05   4.41e+04      4.546      0.000     1.1e+05    2.91e+05
# CameraBattery            2.869e+05   4.21e+04      6.808      0.000    2.01e+05    3.73e+05
# CameraBatteryGrip        7.906e+04   2.59e+04      3.052      0.005    2.61e+04    1.32e+05
# CameraMicrophone        -7.387e+04   2.59e+04     -2.849      0.008   -1.27e+05   -2.08e+04
# CameraTripod             1.732e+05   2.88e+04      6.012      0.000    1.14e+05    2.32e+05
# Filter                   3.118e+05   4.49e+04      6.940      0.000     2.2e+05    4.04e+05
# Flash                    2.463e+05    3.8e+04      6.491      0.000    1.69e+05    3.24e+05
# Strap                    1.274e+05   4.04e+04      3.151      0.004    4.47e+04     2.1e+05
# ReflectorUmbrella       -4.931e+04   3.91e+04     -1.261      0.218   -1.29e+05    3.07e+04
# ==============================================================================
# Omnibus:                        1.779   Durbin-Watson:                   2.054
# Prob(Omnibus):                  0.411   Jarque-Bera (JB):                1.658
# Skew:                           0.461   Prob(JB):                        0.436
# Kurtosis:                       2.651   Cond. No.                         7.18
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
X_train_final.shape
# Out:
# (41, 11)

# %% [markdown]
# ## Using these features to Update Model Training Dataset

# %%
X_train_final.head()
# Out:
#     adStock_Other Marketing  total_pay_days  Binoculars  CameraBattery  \
# 6                   -0.5369          1.1304     -1.9182        -2.3215
# 41                  -0.5104         -0.8847     -0.4877        -1.1971
# 2                   -0.5369          1.1304      0.0339         0.3182
# 42                  -0.5369          1.1304      2.1362         2.2654
# 34                   0.7356          1.1304     -0.2269         1.0141
#
#     CameraBatteryGrip  CameraMicrophone  CameraTripod  Filter   Flash   Strap  \
# 6             -1.7084           -0.5373       -1.3518 -1.6251 -1.2200 -2.0489
# 41            -1.4499            0.0000       -0.6782 -0.7327 -0.3741 -0.0339
# 2             -0.4161           -0.5373       -0.3007 -0.2829 -1.1903 -0.3813
# 42             0.8762            1.0747        0.8919  1.4804  2.0991  3.0234
# 34             0.3593            2.6867       -0.1291  0.2239  0.5953  1.1473
#
#     ReflectorUmbrella
# 6                   0
# 41                  0
# 2                   0
# 42                  0
# 34                  0

# %%
X_test_final = X_test_rfe[X_train_final.columns]

# %% [markdown]
# ## Model Performance of the Optimized Model

# %%
def evaluate_model(model, X, y, dataset_name="Test", log_transform=False):
    """
    Evaluates model performance on given dataset (Train/Test) using R², MAE, MSE, and RMSE.
    Ensures only features used in final_model are passed to avoid shape mismatch.
    Logs results to MLflow for tracking.
    """
    # Extract actual features used in the model
    model_features = model.model.exog_names  # Includes 'const'

    # Ensure 'const' is present in the DataFrame
    if "const" not in X.columns:
        X_final = sm.add_constant(X)
    else:
        X_final = X.copy()

    # Select only model features (to avoid shape mismatch)
    X_final = X_final[model_features]

    # Predict
    y_pred = model.predict(X_final)

    # **Handle Log Transformation (if applied)**
    if log_transform:
        y_pred_original = np.exp(y_pred)
        y_original = np.exp(y)  # Convert actual values back to original scale
    else:
        y_pred_original = y_pred
        y_original = y

    # **Check for NaN or Infinity**
    if np.any(np.isnan(y_original)) or np.any(np.isinf(y_original)):
        raise ValueError(f"NaN or Infinity detected in {dataset_name} actual values!")
    if np.any(np.isnan(y_pred_original)) or np.any(np.isinf(y_pred_original)):
        raise ValueError(f"NaN or Infinity detected in {dataset_name} predicted values!")

    # Compute Evaluation Metrics
    r2 = r2_score(y_original, y_pred_original)
    mae = mean_absolute_error(y_original, y_pred_original)
    mse = mean_squared_error(y_original, y_pred_original)
    rmse = np.sqrt(mse)

    # Print Results
    print(f"\n===== Model Performance on {dataset_name} Data =====")
    print(f"R² Score: {r2:.4f}")
    print(f"MAE: {mae:.2f}")
    print(f"MSE: {mse:.2f}")
    print(f"RMSE: {rmse:.2f}")

    # Log to MLflow
    mlflow.log_metric(f"{dataset_name} R-squared", r2)
    mlflow.log_metric(f"{dataset_name} MAE", mae)
    mlflow.log_metric(f"{dataset_name} MSE", mse)
    mlflow.log_metric(f"{dataset_name} RMSE", rmse)
    mlflow.log_param(f"{dataset_name} Features Used", len(model_features))

    return y_pred_original

# %%
# Evaluate model performance on TRAIN data
y_train_pred = evaluate_model(final_model, X_train_final, y_train, dataset_name="Train")

# Evaluate model performance on TEST data
y_test_pred = evaluate_model(final_model, X_test_final, y_test, dataset_name="Test")
# Out:
# ===== Model Performance on Train Data =====
# R² Score: 0.9925
# MAE: 77622.38
# MSE: 9265484981.50
# RMSE: 96257.39
#
# ===== Model Performance on Test Data =====
# R² Score: 0.9471
# MAE: 157730.67
# MSE: 41626356959.53
# RMSE: 204025.38

# %%
def plot_predictions(y_test, y_test_pred):
    """
    Plots actual GMV vs predicted GMV with enhancements.
    """
    plt.figure(figsize=(7,7))
    
    # Scatterplot with density coloring
    sns.scatterplot(x=y_test, y=y_test_pred, alpha=0.5)
    
    # Ideal prediction line
    plt.axline((0,0), slope=1, color="red", linestyle="dashed", linewidth=2, label="Ideal Fit (y=x)")
    
    # Labels & title
    plt.xlabel("Actual GMV")
    plt.ylabel("Predicted GMV")
    plt.title("Actual vs Predicted GMV")

    # Annotate R² Score
    r2 = r2_score(y_test, y_test_pred)
    plt.text(min(y_test), max(y_test_pred), f"R²: {r2:.4f}", fontsize=12, color="blue")

    plt.legend()
    plt.show()


# Visualize Predictions
plot_predictions(y_test, y_test_pred)

# %%
def plot_residuals(y_test, y_test_pred):
    """
    Plots residuals to check model stability with improvements.
    """
    residuals = y_test - y_test_pred
    
    plt.figure(figsize=(7,5))
    
    # Scatter plot with different colors for negative vs. positive residuals
    sns.scatterplot(x=y_test_pred, y=residuals, hue=residuals > 0, palette={True: "blue", False: "orange"}, alpha=0.6)

    plt.axhline(y=0, color="red", linestyle="dashed", linewidth=2)
    
    # Labels & title
    plt.xlabel("Predicted GMV")
    plt.ylabel("Residuals")
    plt.title("Residual Plot")
    
    plt.legend(["Zero Error Line", "Over-prediction", "Under-prediction"])
    plt.grid(axis="y", linestyle="--", alpha=0.6)

    plt.show()



# Check Residuals for Model Stability
plot_residuals(y_test, y_test_pred)

# %% [markdown]
# ## Model Elasticity

# %%
# import pandas as pd

# # Compute elasticity values
# elasticity = {}
# valid_features = final_model.params.index.tolist()  # Get features in final model

# for feature in X_train_final.columns:
#     if feature in valid_features:  # Ensure feature exists in model params
#         feature_mean = X_train_final[feature].mean()
#         coef = final_model.params[feature]
#         elasticity[feature] = (coef * feature_mean) / y_train.mean()

# # Convert to DataFrame
# elasticity_df = pd.DataFrame(list(elasticity.items()), columns=["Feature", "Elasticity"])

# # Display elasticity values
# from IPython.display import display
# display(elasticity_df)

# %%
def get_elasticity(X_train_original, X_train_scaled, y_train, model):
    """
    Computes elasticity using original feature means instead of scaled values.
    This ensures more realistic elasticity values.
    """
    elasticity = {}
    valid_features = set(model.params.index.tolist())  # Features in final model

    for feature in X_train_scaled.columns:  # Use scaled feature names
        if feature in valid_features:
            feature_mean_original = X_train_original[feature].mean()  # Use original means
            coef = model.params[feature]
            elasticity[feature] = (coef * feature_mean_original) / (y_train.mean() + 1e-9)

    # Convert to DataFrame
    elasticity_df = pd.DataFrame(list(elasticity.items()), columns=["Feature", "Elasticity"])
    
    # Sort by absolute elasticity to highlight impact
    elasticity_df = elasticity_df.sort_values("Elasticity", ascending=False, key=abs)

    return elasticity_df

# Compute Elasticity (Using original data before scaling)
elasticity_df = get_elasticity(X_train, X_train_final_scaled, y_train, final_model)

# ✅ **Plot Updated Elasticity**
plt.figure(figsize=(8,5))
sns.barplot(y="Feature", x="Elasticity", data=elasticity_df, palette="coolwarm")  # Better color scheme
plt.xlabel("Elasticity")
plt.ylabel("Feature")
plt.title("Elasticity of Key Variables")

# Add zero reference line
plt.axvline(x=0, color="red", linestyle="--")

plt.show()

# %%
# Normalize Elasticity Values (convert to percentages)
elasticity_df["Normalized Elasticity"] = (elasticity_df["Elasticity"] / elasticity_df["Elasticity"].abs().max()) * 100

# Create Absolute Elasticity Column
elasticity_df["Absolute Elasticity"] = elasticity_df["Elasticity"].abs()

# Sort by absolute elasticity for better visualization
elasticity_df = elasticity_df.sort_values("Absolute Elasticity", ascending=False)

# Plot side-by-side
fig, axes = plt.subplots(1, 2, figsize=(16, 5))

# Normalized Elasticity Plot (Percentage)
sns.barplot(y="Feature", x="Normalized Elasticity", data=elasticity_df, ax=axes[0], palette="Blues_r")
axes[0].set_title("Normalized Elasticity (Percentage)")
axes[0].set_xlabel("Elasticity (%)")
axes[0].axvline(x=0, color="red", linestyle="--")

# Absolute Elasticity Plot
sns.barplot(y="Feature", x="Absolute Elasticity", data=elasticity_df, ax=axes[1], palette="coolwarm")
axes[1].set_title("Absolute Elasticity (Magnitude)")
axes[1].set_xlabel("Absolute Elasticity")
axes[1].axvline(x=0, color="red", linestyle="--")

plt.tight_layout()
plt.show()

# %% [markdown]
# # Ridge Regularization

# %% [markdown]
# ## Base Ridge Model

# %%
ridge_model = Ridge(alpha=1.0)  # Initial model with default alpha=1
ridge_model.fit(X_train_final, y_train)

# Predict on Train and Test
y_train_pred_ridge = ridge_model.predict(X_train_final)
y_test_pred_ridge = ridge_model.predict(X_test_final)

# Evaluate model performance
def evaluate_ridge_model(model, X, y, dataset_name="Test"):
    """
    Evaluates Ridge model performance on given dataset using R², MAE, MSE, and RMSE.
    """
    # Predict
    y_pred = model.predict(X)

    # Compute evaluation metrics
    r2 = r2_score(y, y_pred)
    mae = mean_absolute_error(y, y_pred)
    mse = mean_squared_error(y, y_pred)
    rmse = np.sqrt(mse)

    # Print results
    print(f"\n===== Ridge Model Performance on {dataset_name} Data =====")
    print(f"R² Score: {r2:.4f}")
    print(f"MAE: {mae:.2f}")
    print(f"MSE: {mse:.2f}")
    print(f"RMSE: {rmse:.2f}")

    return r2, mae, mse, rmse

# Evaluate Ridge on train and test
evaluate_ridge_model(ridge_model, X_train_final, y_train, dataset_name="Train")
evaluate_ridge_model(ridge_model, X_test_final, y_test, dataset_name="Test")
# Out:
# ===== Ridge Model Performance on Train Data =====
# R² Score: 0.9923
# MAE: 77640.56
# MSE: 9408373898.73
# RMSE: 96996.77
#
# ===== Ridge Model Performance on Test Data =====
# R² Score: 0.9471
# MAE: 160912.95
# MSE: 41577492562.87
# RMSE: 203905.60
# (0.9471404904070078, 160912.95133026008, 41577492562.87274, 203905.59718377705)

# %% [markdown]
# ## Looking at Ridge Regression in different values of alpha

# %%
# Define alpha values to test (same range as before)
alpha_values = np.logspace(np.log10(0.01), np.log10(20), 20)

# Store results
train_r2, test_r2 = [], []
train_rmse, test_rmse = [], []
train_mae, test_mae = [], []

# Loop through each alpha value and train Ridge model
for alpha in alpha_values:
    ridge_model = Ridge(alpha=alpha)
    ridge_model.fit(X_train_final, y_train)  # Updated dataset
    y_train_pred = ridge_model.predict(X_train_final)  # Updated dataset
    y_test_pred = ridge_model.predict(X_test_final)  # Updated dataset

    # Store metrics
    train_r2.append(r2_score(y_train, y_train_pred))
    test_r2.append(r2_score(y_test, y_test_pred))
    train_rmse.append(np.sqrt(mean_squared_error(y_train, y_train_pred)))
    test_rmse.append(np.sqrt(mean_squared_error(y_test, y_test_pred)))
    train_mae.append(mean_absolute_error(y_train, y_train_pred))
    test_mae.append(mean_absolute_error(y_test, y_test_pred))

# Plot R² Scores
plt.figure(figsize=(8,5))
plt.plot(alpha_values, train_r2, marker='o', label="Train R²")
plt.plot(alpha_values, test_r2, marker='s', label="Test R²")
plt.xscale("log")
plt.xlabel("Alpha Value (log scale)")
plt.ylabel("R² Score")
plt.title("R² Score vs. Ridge Alpha")
plt.legend()
plt.show()

# Plot RMSE Scores
plt.figure(figsize=(8,5))
plt.plot(alpha_values, train_rmse, marker='o', label="Train RMSE")
plt.plot(alpha_values, test_rmse, marker='s', label="Test RMSE")
plt.xscale("log")
plt.xlabel("Alpha Value (log scale)")
plt.ylabel("RMSE")
plt.title("RMSE vs. Ridge Alpha")
plt.legend()
plt.show()

# Plot MAE Scores
plt.figure(figsize=(8,5))
plt.plot(alpha_values, train_mae, marker='o', label="Train MAE")
plt.plot(alpha_values, test_mae, marker='s', label="Test MAE")
plt.xscale("log")
plt.xlabel("Alpha Value (log scale)")
plt.ylabel("MAE")
plt.title("MAE vs. Ridge Alpha")
plt.legend()
plt.show()

# %% [markdown]
# ## Grid Search CV for Ridge

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Ridge

# Define the alpha search space
ridge_params = {'alpha': np.logspace(-3, 3, 100)}

# Perform Grid Search Cross-Validation to find the best alpha
ridge_grid = GridSearchCV(Ridge(), ridge_params, scoring='r2', cv=5)
ridge_grid.fit(X_train_final, y_train)  

# Get the best alpha value
best_alpha = ridge_grid.best_params_['alpha']
print(f"\nBest Alpha from GridSearchCV: {best_alpha}")

# Train the final Ridge model with the best alpha
ridge_best = Ridge(alpha=best_alpha)
ridge_best.fit(X_train_final, y_train)  

# Evaluate the final Ridge model
evaluate_ridge_model(ridge_best, X_train_final, y_train, dataset_name="Train")  
evaluate_ridge_model(ridge_best, X_test_final, y_test, dataset_name="Test")
# Out:
# Best Alpha from GridSearchCV: 2.1544346900318843
#
# ===== Ridge Model Performance on Train Data =====
# R² Score: 0.9920
# MAE: 79866.57
# MSE: 9829760292.84
# RMSE: 99145.15
#
# ===== Ridge Model Performance on Test Data =====
# R² Score: 0.9471
# MAE: 163045.50
# MSE: 41623063122.49
# RMSE: 204017.31
# (0.9470825543150297, 163045.49994596577, 41623063122.49169, 204017.31084026102)

# %% [markdown]
# ## Getting Coefficients & Feature Importance of Best Ridge Model

# %%
# Extract Ridge coefficients using the correct feature set
ridge_coefficients = pd.DataFrame({"Feature": X_train_final.columns, "Coefficient": ridge_best.coef_})
ridge_coefficients = ridge_coefficients.sort_values(by="Coefficient", ascending=False)

# Plot Ridge coefficients
plt.figure(figsize=(10, 6))
sns.barplot(y=ridge_coefficients["Feature"], x=ridge_coefficients["Coefficient"], palette="coolwarm")
plt.title("Feature Importance (Ridge Coefficients)")
plt.xlabel("Coefficient Value")
plt.ylabel("Feature")
plt.axvline(x=0, color="red", linestyle="--")
plt.show()

# %% [markdown]
# ## VIF Check

# %%
def calculate_vif(X):
    """
    Computes Variance Inflation Factor (VIF) to check multicollinearity.
    """
    vif_data = pd.DataFrame()
    vif_data["Feature"] = X.columns
    vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
    return vif_data.sort_values(by="VIF", ascending=False)

# Calculate VIF using the optimized feature set
ridge_vif = calculate_vif(X_train_final)

print("\nVariance Inflation Factor (VIF) after Ridge Regression:")
print(ridge_vif)
# Out:
# Variance Inflation Factor (VIF) after Ridge Regression:
#                     Feature    VIF
# 7                    Filter 6.3177
# 2                Binoculars 6.0867
# 3             CameraBattery 5.5601
# 9                     Strap 5.1181
# 8                     Flash 4.5048
# 6              CameraTripod 2.5985
# 5          CameraMicrophone 2.1037
# 4         CameraBatteryGrip 2.0987
# 0   adStock_Other Marketing 1.4863
# 1            total_pay_days 1.1406
# 10        ReflectorUmbrella 1.1174

# %% [markdown]
# ## Ridge Model Predictions

# %%
def plot_predictions(y_test, y_test_pred):
    plt.figure(figsize=(7,7))
    sns.scatterplot(x=y_test, y=y_test_pred, alpha=0.5)
    plt.axline((0,0), slope=1, color="red", linestyle="dashed", linewidth=2, label="Ideal Fit (y=x)")
    plt.xlabel("Actual GMV")
    plt.ylabel("Predicted GMV")
    plt.title("Actual vs Predicted GMV")
    plt.legend()
    plt.show()

# Generate predictions using the correct test set
plot_predictions(y_test, ridge_best.predict(X_test_final))

# %% [markdown]
# ## Residuals Plot

# %%
def plot_residuals(y_test, y_test_pred):
    residuals = y_test - y_test_pred
    plt.figure(figsize=(7,5))
    sns.scatterplot(x=y_test_pred, y=residuals, hue=residuals > 0, palette={True: "blue", False: "orange"}, alpha=0.6)
    plt.axhline(y=0, color="red", linestyle="dashed", linewidth=2)
    plt.xlabel("Predicted GMV")
    plt.ylabel("Residuals")
    plt.title("Residual Plot")
    plt.legend(["Zero Error Line", "Over-prediction", "Under-prediction"])
    plt.grid(axis="y", linestyle="--", alpha=0.6)
    plt.show()

# Generate residual plot using the correct test dataset
plot_residuals(y_test, ridge_best.predict(X_test_final))

# %% [markdown]
# ## Ridge Elasticity Plot

# %%
# # Compute Elasticity using the correct dataset
# ridge_coefficients["Elasticity"] = ridge_coefficients["Coefficient"] * np.std(X_train_final, axis=0) / np.std(y_train)
# ridge_coefficients["Absolute Elasticity"] = ridge_coefficients["Elasticity"].abs()
# ridge_coefficients = ridge_coefficients.sort_values(by="Absolute Elasticity", ascending=False)

# # Plot Elasticity
# plt.figure(figsize=(10,6))
# sns.barplot(y="Feature", x="Elasticity", data=ridge_coefficients, palette="coolwarm")
# plt.title("Feature Elasticity")
# plt.xlabel("Elasticity")
# plt.axvline(x=0, color="red", linestyle="--")
# plt.show()

# %% [markdown]
# # Elasti Net Regularization

# %% [markdown]
# ## Training the Initial Elasti Net Model

# %%
# Train ElasticNet model with default alpha and l1_ratio (50% L1, 50% L2)
elasticnet_model = ElasticNet(alpha=1.0, l1_ratio=0.5)  
elasticnet_model.fit(X_train_final, y_train)

# Predict on Train and Test
y_train_pred_en = elasticnet_model.predict(X_train_final)
y_test_pred_en = elasticnet_model.predict(X_test_final)

# Evaluate ElasticNet model performance
evaluate_ridge_model(elasticnet_model, X_train_final, y_train, dataset_name="Train")
evaluate_ridge_model(elasticnet_model, X_test_final, y_test, dataset_name="Test")
# Out:
# ===== Ridge Model Performance on Train Data =====
# R² Score: 0.9755
# MAE: 138522.35
# MSE: 30030859354.62
# RMSE: 173294.14
#
# ===== Ridge Model Performance on Test Data =====
# R² Score: 0.9380
# MAE: 193136.53
# MSE: 48778095762.05
# RMSE: 220857.64
# (0.937986009691108, 193136.5344380674, 48778095762.05079, 220857.63686603817)

# %% [markdown]
# ## Evaluate ElasticNet Across Different Alpha Values

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import ElasticNet

# Define alpha values to test
alpha_values = np.logspace(np.log10(0.01), np.log10(20), 20)

# Store results
train_r2, test_r2 = [], []
train_rmse, test_rmse = [], []
train_mae, test_mae = [], []

# Loop through each alpha value and train ElasticNet model
for alpha in alpha_values:
    elasticnet_model = ElasticNet(alpha=alpha, l1_ratio=0.5)  # Keeping l1_ratio constant at 0.5 for now
    elasticnet_model.fit(X_train_final, y_train)
    y_train_pred = elasticnet_model.predict(X_train_final)
    y_test_pred = elasticnet_model.predict(X_test_final)

    # Store metrics
    train_r2.append(r2_score(y_train, y_train_pred))
    test_r2.append(r2_score(y_test, y_test_pred))
    train_rmse.append(np.sqrt(mean_squared_error(y_train, y_train_pred)))
    test_rmse.append(np.sqrt(mean_squared_error(y_test, y_test_pred)))
    train_mae.append(mean_absolute_error(y_train, y_train_pred))
    test_mae.append(mean_absolute_error(y_test, y_test_pred))

# Plot R² Scores
plt.figure(figsize=(8,5))
plt.plot(alpha_values, train_r2, marker='o', label="Train R²")
plt.plot(alpha_values, test_r2, marker='s', label="Test R²")
plt.xscale("log")
plt.xlabel("Alpha Value (log scale)")
plt.ylabel("R² Score")
plt.title("R² Score vs. ElasticNet Alpha")
plt.legend()
plt.show()

# Plot RMSE Scores
plt.figure(figsize=(8,5))
plt.plot(alpha_values, train_rmse, marker='o', label="Train RMSE")
plt.plot(alpha_values, test_rmse, marker='s', label="Test RMSE")
plt.xscale("log")
plt.xlabel("Alpha Value (log scale)")
plt.ylabel("RMSE")
plt.title("RMSE vs. ElasticNet Alpha")
plt.legend()
plt.show()

# Plot MAE Scores
plt.figure(figsize=(8,5))
plt.plot(alpha_values, train_mae, marker='o', label="Train MAE")
plt.plot(alpha_values, test_mae, marker='s', label="Test MAE")
plt.xscale("log")
plt.xlabel("Alpha Value (log scale)")
plt.ylabel("MAE")
plt.title("MAE vs. ElasticNet Alpha")
plt.legend()
plt.show()

# %% [markdown]
# ## Hyperparameter Tuning (GridSearchCV)

# %%
# Define hyperparameter grid
elasticnet_params = {
    'alpha': np.logspace(-3, 3, 100),  # Alpha range
    'l1_ratio': np.linspace(0.1, 1, 10)  # Varying L1 penalty (closer to 1 is Lasso, closer to 0 is Ridge)
}

# Perform Grid Search Cross-Validation
elasticnet_grid = GridSearchCV(ElasticNet(), elasticnet_params, scoring='r2', cv=5, n_jobs=-1)
elasticnet_grid.fit(X_train_final, y_train)

# Get the best hyperparameters
best_alpha = elasticnet_grid.best_params_['alpha']
best_l1_ratio = elasticnet_grid.best_params_['l1_ratio']
print(f"\nBest Alpha from GridSearchCV: {best_alpha}")
print(f"Best L1 Ratio from GridSearchCV: {best_l1_ratio}")
# Out:
# Best Alpha from GridSearchCV: 0.13219411484660287
# Best L1 Ratio from GridSearchCV: 0.5

# %% [markdown]
# ## Train Final ElasticNet Model

# %%
# Train final ElasticNet model with best hyperparameters
elasticnet_best = ElasticNet(alpha=best_alpha, l1_ratio=best_l1_ratio)
elasticnet_best.fit(X_train_final, y_train)

# Evaluate final ElasticNet model
evaluate_ridge_model(elasticnet_best, X_train_final, y_train, dataset_name="Train")
evaluate_ridge_model(elasticnet_best, X_test_final, y_test, dataset_name="Test")
# Out:
# ===== Ridge Model Performance on Train Data =====
# R² Score: 0.9918
# MAE: 81814.06
# MSE: 10102751239.29
# RMSE: 100512.44
#
# ===== Ridge Model Performance on Test Data =====
# R² Score: 0.9470
# MAE: 164138.87
# MSE: 41664943709.50
# RMSE: 204119.92
# (0.9470293094665757, 164138.87070545918, 41664943709.49782, 204119.9248223892)

# %% [markdown]
# ## Feature Importance (ElasticNet Coefficients)

# %%
# Extract coefficients
elasticnet_coefficients = pd.DataFrame({"Feature": X_train_final.columns, "Coefficient": elasticnet_best.coef_})
elasticnet_coefficients = elasticnet_coefficients.sort_values(by="Coefficient", ascending=False)

# Plot coefficients
plt.figure(figsize=(10,6))
sns.barplot(y=elasticnet_coefficients["Feature"], x=elasticnet_coefficients["Coefficient"], palette="coolwarm")
plt.title("Feature Importance (ElasticNet Coefficients)")
plt.xlabel("Coefficient Value")
plt.ylabel("Feature")
plt.axvline(x=0, color="red", linestyle="--")
plt.show()

# %% [markdown]
# ## Calculate VIF for ElasticNet

# %%
elasticnet_vif = calculate_vif(X_train_final)

print("\nVariance Inflation Factor (VIF) after ElasticNet Regression:")
print(elasticnet_vif)
# Out:
# Variance Inflation Factor (VIF) after ElasticNet Regression:
#                     Feature    VIF
# 7                    Filter 6.3177
# 2                Binoculars 6.0867
# 3             CameraBattery 5.5601
# 9                     Strap 5.1181
# 8                     Flash 4.5048
# 6              CameraTripod 2.5985
# 5          CameraMicrophone 2.1037
# 4         CameraBatteryGrip 2.0987
# 0   adStock_Other Marketing 1.4863
# 1            total_pay_days 1.1406
# 10        ReflectorUmbrella 1.1174

# %% [markdown]
# ## Plot Predictions and Residual Plots

# %%
# Prediction Plot
plot_predictions(y_test, elasticnet_best.predict(X_test_final))

# Residual Plot
plot_residuals(y_test, elasticnet_best.predict(X_test_final))

# %%
# # Compute Elasticity using the correct dataset
# elasticnet_coefficients["Elasticity"] = elasticnet_coefficients["Coefficient"] * np.std(X_train_final, axis=0) / np.std(y_train)
# elasticnet_coefficients["Absolute Elasticity"] = elasticnet_coefficients["Elasticity"].abs()
# elasticnet_coefficients = elasticnet_coefficients.sort_values(by="Absolute Elasticity", ascending=False)

# # If Elasticity values are too small, scale them up
# if elasticnet_coefficients["Elasticity"].abs().max() < 0.01:
#     print("Elasticity values are too small, scaling up...")
#     elasticnet_coefficients["Elasticity"] *= 100  

# # Plot Elasticity
# plt.figure(figsize=(10,6))
# sns.barplot(y="Feature", x="Elasticity", data=elasticnet_coefficients, palette="coolwarm")
# plt.title("Feature Elasticity")
# plt.xlabel("Elasticity")
# plt.axvline(x=0, color="red", linestyle="--")
# plt.show()
